# %%
from pyspark.sql.types import StringType
import pyspark.sql.functions as F

# %%
from pyspark.sql import SparkSession 
builder = SparkSession.builder

spark = (builder
          .config('spark.driver.maxResultSize', '21000m')
          .config('spark.scheduler.mode', 'FIFO')
          .config('spark.executor.memory', '15000m')
         ).getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://c-kla-d483871b-c8ae-47ad-b996-4f89c8888680-m.c.tr-infra-dataproc-prod.internal:41005">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.7</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
raw_reader = (
  spark
  .read
  .option("parentProject" ,'tr-tech-innovation-dev')     
  .option('project','tr-tech-innovation-dev')
#   .option("credentialsFile", credentials_file)
  .format("bigquery")
  .option("dataset", "merchant")
)


reader = raw_reader.option("filter", "_PARTITIONDATE = '2020-10-26'")

# %%
products = (reader
  .option('table', 'Products_8215388')
  .load()
)

# %%
products.groupby('offer_id').count().groupby('count').count().show()
# Out:
# +-----+-----+
# |count|count|
# +-----+-----+
# |    1|10156|
# +-----+-----+

# %%
topBrands4weeks = (reader
  .option('table', 'BestSellers_TopBrands_8090258')
  .option('filter', '_PARTITIONDATE in ("2020-10-05","2020-10-12","2020-10-19","2020-10-26")')
  .load()
)

from pyspark.storagelevel import StorageLevel
# topBrands4weeks.persist(StorageLevel.DISK_ONLY).count()
topBrands4weeks.cache().count()

# %%
# Out:
# 5359219

# %%
bucket = "bkt-dataproc-prod-eu-notebookmarouaneazlaf"

# %%
topBrands4weeks.write.parquet(f'gs://{bucket}/klarna/topBrands4weeks.parquet')

# %%
# !gsutil cp gs://{bucket}/klarna/datalyer.json  .
# Out:
# Copying gs://bkt-dataproc-prod-eu-notebookmarouaneazlaf/klarna/datalyer.json...
# / [1 files][337.5 KiB/337.5 KiB]
# Operation completed over 1 objects/337.5 KiB.

# %%
# gs://bkt-dataproc-prod-eu-notebookmarouaneazlaf/klarna/datalyer.json

# %%
import pandas as pd
import json

with open('datalyer.json') as f : 
    datalyer = json.load(f)

merchants = pd.DataFrame([l for d in datalyer  if 'block.cards' in d for l in d['block.cards']])    
merchants_df = spark.createDataFrame(merchants)

# %%
klarna_merchants = merchants_df.withColumnRenamed('title','name')
my_brands = topBrands4weeks.join(klarna_merchants,klarna_merchants.name == topBrands4weeks.brand,'inner')
my_brands.cache().count()
# Out:
# 86925

# %%
us_brands = (my_brands
             .filter('ranking_country = "US" ')

            .select('*', 
                    F.explode('ranking_category_path').alias('cat')
            )
            .filter('cat.locale = "en-US"')
 .drop('ranking_category_path')
)

# %%
matching_cat_ids = {d['name']:d['ranking_category'] for d in (us_brands
#  .filter(~F.col('cat.name').contains('>'))
 .filter(F.size(F.split('cat.name','>')) < 3)
 .groupBy('cat.name','ranking_category')
 .agg(F.countDistinct('brand').alias('brands'))
 .orderBy('name')
).toPandas().to_dict('records')}

# %%
cat_matching = {'Electronics > Audio' : "Electronics",
'Apparel & Accessories > Clothing': "Clothes & fashion",
'Apparel & Accessories > Jewelry': "Clothes & fashion",
'Apparel & Accessories > Shoes': "Clothes & fashion",
'Health & Beauty > Health Care': "Health",
'Health & Beauty > Personal Care': "Beauty",
'Home & Garden > Decor': "Home",
'Home & Garden > Kitchen & Dining': "Home",
'Home & Garden > Linens & Bedding': "Home",
'Luggage & Bags': 'Luggage',
'Sporting Goods': 'Sport',
 "Toys & Games": 'Toys & entertainment',
 "Furniture": "Home"}

# %%
from functools import reduce
col2 = reduce(lambda y,srcdest: F.when(F.col('ranking_category') == matching_cat_ids.get(srcdest[0]),srcdest[1] ).otherwise(y),cat_matching.items(),None).alias('my_cat')

# %%
us_brands_2 = us_brands.select('*', col2)

# %%
other_brands = topBrands4weeks.select('rank','brand','ranking_country', col2)
other_brands_us = other_brands.filter('ranking_country = "US" ')

# %%
from itertools import zip_longest

for v in set(cat_matching.values()): 
    print(v)
    my_brands_str = (us_brands_2
     .filter(F.col('my_cat') == v  )
     .groupby(F.col('brand').alias('k_brands'), 'ranking_country')
     .agg(F.min('rank').alias('min_rank'), F.max('rank').alias('max_rank'))
     .orderBy(F.asc('min_rank'))
     .limit(10)
    )._jdf.showString(10,50,False)

    all_brands_str = (other_brands_us
     .filter(F.col('my_cat') == v  )
     .groupby(F.col('brand').alias('all_brands'), 'ranking_country')
     .agg(F.min('rank').alias('min_rank'), F.max('rank').alias('max_rank'))
     .orderBy(F.asc('min_rank'))
     .limit(10)
    )._jdf.showString(10,50,False)

    # rising_brands_str = (other_brands_us
    #  .filter(F.col('my_cat') == v  )
    #  .groupby(F.col('brand').alias('rising_brands'), 'ranking_country')
    #  .agg(F.min('rank').alias('min_rank'), F.max('rank').alias('max_rank'))
    #  .orderBy(F.asc('min_rank'))
    # )._jdf.showString(20,50,False)
    for a,b in zip_longest(my_brands_str.split('\n'),all_brands_str.split('\n')):
        print(b,'' if not a else a)
# Out:
# Beauty
# +-----------------+---------------+--------+--------+ +-------------+---------------+--------+--------+
# |       all_brands|ranking_country|min_rank|max_rank| |     k_brands|ranking_country|min_rank|max_rank|
# +-----------------+---------------+--------+--------+ +-------------+---------------+--------+--------+
# |     The Ordinary|             US|       1|       1| | Calvin Klein|             US|      62|      74|
# |          L'Oréal|             US|       2|       4| |Mario Badescu|             US|     140|     165|
# |          Philips|             US|       2|       3| |     Givenchy|             US|     151|     159|
# |           Revlon|             US|       3|       6| |Beautycounter|             US|     203|     328|
# |Bath & Body Works|             US|       4|       5| |        SHEIN|             US|     241|     283|
# |            M·A·C|             US|       5|       8| |    Bio Ionic|             US|     273|     341|
# |             Dior|             US|       6|      10| |  Perry Ellis|             US|     421|     491|
# |           CeraVe|             US|       6|      10| |      Nautica|             US|     486|     561|
# |        Eyefusion|             US|       7|      62| |   Brookstone|             US|     532|     607|
# |           CHANEL|             US|       7|      11| |    Hollister|             US|     567|     629|
# +-----------------+---------------+--------+--------+ +-------------+---------------+--------+--------+
#
# Electronics
# +------------+---------------+--------+--------+ +----------------+---------------+--------+--------+
# |  all_brands|ranking_country|min_rank|max_rank| |        k_brands|ranking_country|min_rank|max_rank|
# +------------+---------------+--------+--------+ +----------------+---------------+--------+--------+
# |       Apple|             US|       1|       1| |            Bose|             US|       2|       2|
# |        Bose|             US|       2|       2| |             JBL|             US|       3|       4|
# |        Sony|             US|       3|       5| |           Sonos|             US|      28|      31|
# |         JBL|             US|       3|       4| |           SHEIN|             US|      58|      61|
# |       Beats|             US|       4|       5| |       Case-Mate|             US|     132|     318|
# |    Logitech|             US|       6|       9| |Master & Dynamic|             US|     139|     160|
# |      Google|             US|       6|       9| |          Lenovo|             US|     142|     264|
# |     Samsung|             US|       7|       8| |          Fender|             US|     174|     206|
# |      Amazon|             US|       7|      10| |          V-MODA|             US|     184|     235|
# |Turtle Beach|             US|       8|      10| |        CASETiFY|             US|     260|     309|
# +------------+---------------+--------+--------+ +----------------+---------------+--------+--------+
#
# Clothes & fashion
# +----------+---------------+--------+--------+ +--------------+---------------+--------+--------+
# |all_brands|ranking_country|min_rank|max_rank| |      k_brands|ranking_country|min_rank|max_rank|
# +----------+---------------+--------+--------+ +--------------+---------------+--------+--------+
# |     Apple|             US|       1|       1| |        adidas|             US|       2|     659|
# |      Nike|             US|       1|     397| |         SHEIN|             US|       3|      45|
# |     Zales|             US|       2|       3| |The North Face|             US|       7|      56|
# |  Old Navy|             US|       2|     802| |         ROMWE|             US|       9|     240|
# |    adidas|             US|       2|     659| |     Swarovski|             US|      11|    2208|
# |   PANDORA|             US|       2|       3| |    Timberland|             US|      12|    1284|
# |       UGG|             US|       3|     264| |      Fanatics|             US|      12|    1150|
# |      Vans|             US|       3|    1337| |        Reebok|             US|      17|     172|
# |     SHEIN|             US|       3|      45| |        Macy's|             US|      18|    5584|
# |       Gap|             US|       4|      95| |        Clarks|             US|      18|      21|
# +----------+---------------+--------+--------+ +--------------+---------------+--------+--------+
#
# Luggage
# +-------------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
# |         all_brands|ranking_country|min_rank|max_rank| |      k_brands|ranking_country|min_rank|max_rank|
# +-------------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
# |               Nike|             US|       1|       1| |The North Face|             US|       2|       4|
# |              COACH|             US|       2|       6| |      JanSport|             US|       5|      11|
# |     The North Face|             US|       2|       4| |        adidas|             US|       7|       8|
# |       Pottery Barn|             US|       3|       5| |         SHEIN|             US|      20|      25|
# |          Samsonite|             US|       3|       8| |   Eagle Creek|             US|      55|      73|
# |Herschel Supply Co.|             US|       4|       6| |         ROMWE|             US|      86|      99|
# |           JanSport|             US|       5|      11| |  Calvin Klein|             US|     104|     149|
# |             adidas|             US|       7|       8| |          ASOS|             US|     120|     159|
# |          Patagonia|             US|       8|      14| |           MCM|             US|     126|     134|
# |       Vera Bradley|             US|       9|       9| |Tommy Hilfiger|             US|     135|     145|
# +-------------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
#
# Sport
# +-------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
# |   all_brands|ranking_country|min_rank|max_rank| |      k_brands|ranking_country|min_rank|max_rank|
# +-------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
# |      Shimano|             US|       1|       1| |    TaylorMade|             US|      14|      24|
# |      Schwinn|             US|       2|       2| |        adidas|             US|      25|      37|
# |Rogue Fitness|             US|       3|       4| |        Burton|             US|      31|      60|
# |  CAP Barbell|             US|       3|       7| |        Jetson|             US|      55|      80|
# |         Nike|             US|       4|       7| |The North Face|             US|     124|     138|
# |       Wilson|             US|       5|       8| |    Leatherman|             US|     143|     173|
# |        Huffy|             US|       5|     550| |      Gymshark|             US|     341|     489|
# |        Intex|             US|       5|       6| |   Black Crows|             US|     480|     769|
# |         Bell|             US|       8|    3762| |      Fanatics|             US|     530|     713|
# |        Razor|             US|       9|      13| |        Reebok|             US|     688|     845|
# +-------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
#
# Home
# +-----------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
# |       all_brands|ranking_country|min_rank|max_rank| |      k_brands|ranking_country|min_rank|max_rank|
# +-----------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
# |     Pottery Barn|             US|       1|      20| |       iCanvas|             US|      19|    1229|
# |       KitchenAid|             US|       1|    1526| |        Macy's|             US|      56|    1891|
# |        Cuisinart|             US|       1|    1754| |       Nautica|             US|      64|    2899|
# |    Ebern Designs|             US|       1|     255| |         SHEIN|             US|      79|     236|
# | Ashley HomeStore|             US|       1|    2716| |      Fanatics|             US|      81|     156|
# |         Safavieh|             US|       1|     364| |    Brookstone|             US|      86|    1867|
# |     Latitude Run|             US|       2|     904| | Rove Concepts|             US|      96|     100|
# |      Unique Loom|             US|       2|    1260| |           H&M|             US|     151|    2444|
# |     Madison Park|             US|       2|     103| |          IZOD|             US|     152|     177|
# |The Company Store|             US|       3|     596| |Tommy Hilfiger|             US|     162|    3040|
# +-----------------+---------------+--------+--------+ +--------------+---------------+--------+--------+
#
# Health
# +--------------------------+---------------+--------+--------+ +------------------+---------------+--------+--------+
# |                all_brands|ranking_country|min_rank|max_rank| |          k_brands|ranking_country|min_rank|max_rank|
# +--------------------------+---------------+--------+--------+ +------------------+---------------+--------+--------+
# |                    Fitbit|             US|       1|       1| |     Love Wellness|             US|      20|      24|
# |                       NOW|             US|       2|       4| |             Roman|             US|      67|      80|
# |               Nature Made|             US|       2|       3| |             SHEIN|             US|     628|     744|
# |           Puritan's Pride|             US|       3|       4| |            adidas|             US|     883|    1104|
# |             Spring Valley|             US|       5|       8| |         Hollister|             US|    1149|    1244|
# |Drive DeVilbiss Healthcare|             US|       5|       6| |            Burton|             US|    1383|    1448|
# |             Hum Nutrition|             US|       6|      12| |Iron Bull Strength|             US|    2109|    2190|
# |              Nature's Way|             US|       7|      10| +------------------+---------------+--------+--------+
# |                    Garmin|             US|       7|      15|
# |         Optimum Nutrition|             US|       7|      15|
# +--------------------------+---------------+--------+--------+
#
# Toys & entertainment
# +----------------+---------------+--------+--------+ +----------+---------------+--------+--------+
# |      all_brands|ranking_country|min_rank|max_rank| |  k_brands|ranking_country|min_rank|max_rank|
# +----------------+---------------+--------+--------+ +----------+---------------+--------+--------+
# |            LEGO|             US|       1|       1| |  Dynamite|             US|     356|     406|
# |          Hasbro|             US|       2|       2| |  Fanatics|             US|     896|    1084|
# |           Funko|             US|       3|       3| | Lume Cube|             US|    1236|    1426|
# |          Mattel|             US|       4|       4| | Hot Topic|             US|    1252|    1456|
# |          Disney|             US|       5|       5| |Blast Zone|             US|    1398|    1983|
# |    Little Tikes|             US|       6|       7| |Brookstone|             US|    1775|    2003|
# |     Spin Master|             US|       6|       8| |   Nautica|             US|    1901|    2230|
# |L.O.L. Surprise!|             US|       7|       9| +----------+---------------+--------+--------+
# |    Fisher-Price|             US|       8|       9|
# |  Melissa & Doug|             US|      10|      11|
# +----------------+---------------+--------+--------+

# %%
us_brands_2.filter('brand = "JBL"').select('rank', 'rank_timestamp', 'my_cat').where('my_cat is not null').show()
# Out:
# +----+-------------------+-----------+
# |rank|     rank_timestamp|     my_cat|
# +----+-------------------+-----------+
# |4046|2020-10-02 00:00:00|     Beauty|
# |2907|2020-10-02 00:00:00|      Sport|
# |2817|2020-10-02 00:00:00|       Home|
# |   4|2020-10-02 00:00:00|Electronics|
# |4421|2020-10-09 00:00:00|     Beauty|
# |2941|2020-10-09 00:00:00|      Sport|
# |   3|2020-10-09 00:00:00|Electronics|
# |2966|2020-10-16 00:00:00|      Sport|
# |3146|2020-10-16 00:00:00|       Home|
# |   3|2020-10-16 00:00:00|Electronics|
# |   3|2020-10-23 00:00:00|Electronics|
# |2829|2020-10-23 00:00:00|      Sport|
# +----+-------------------+-----------+

# %%
max_timestamp = "2020-10-23 00:00:00"

# %%
from pyspark.sql.window import Window

window = Window.partitionBy("brand","category","ranking_country").orderBy('rank_timestamp')
last_w1 = F.lag('rank',1).over(window).alias('rank_1w')
last_w2 = F.lag('rank',2).over(window).alias('rank_2w')
last_w3 = F.lag('rank',3).over(window).alias('rank_3w')

# %%
brands = (topBrands4weeks
          .select('*', 
                    F.explode('ranking_category_path').alias('cat')
            )
            .filter('cat.locale = "en-US"')
             .drop('ranking_category_path')          
          .select('rank','brand','ranking_country','rank_timestamp','ranking_category',F.col('cat.name').alias('category'), col2)
          .select('*', last_w1,last_w2,last_w3)
          .filter(F.col('rank_timestamp') == max_timestamp )
         )

# %%
my_brands = brands.join(klarna_merchants,klarna_merchants.name == brands.brand,'leftOuter')
my_brands.cache().count()
# Out:
# 1374669

# %%
# my_brands.show()

# %%
# !gsutil -m rm  -r 'gs://{bucket}/klarna/my_brands_full.parquet'

# %%
my_brands.write.parquet(f'gs://{bucket}/klarna/my_brands_fullCategories.parquet')

# %%
my_brands_us = my_brands.where('ranking_country = "US" ')

# %%
# rising = my_brands_us.filter( (F.col('rank') <  0.8 * F.col('rank_1w')) &
#                    (F.col('rank_1w') <  0.8 * F.col('rank_2w')) &
#                     (F.col('rank_2w') < 0.8 * F.col('rank_3w')) &
#                     (F.col('rank') > 10 ) 
#                    ).select('rank','brand','my_cat','rank_1w','rank_2w', 'rank_3w','name')

# %%
ranks = F.concat_ws(' ◄ ','rank_1w','rank_2w', 'rank_3w').alias('ranks')

# %%
my_brands_us.select('category').distinct().count()

# %%
my_brands.head()
# Out:
# Row(rank=642, brand='1 Up Nutrition', ranking_country='US', rank_timestamp=datetime.datetime(2020, 10, 23, 0, 0), ranking_category=2890, category='Health & Beauty > Health Care > Fitness & Nutrition', my_cat=None, rank_1w=613, rank_2w=506, rank_3w=508, position=None, target=None, name=None)

# %%
spark._jsc.hadoopConfiguration().set('fs.gs.impl', 'com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem')
# This is required if you are using service account and set true, 
# spark._jsc.hadoopConfiguration().set('fs.gs.auth.service.account.enable', 'true')
# spark._jsc.hadoopConfiguration().set('google.cloud.auth.service.account.json.keyfile', credentials_file)


(my_brands.withColumn('ranks',ranks).coalesce(1).write
  .option("parentProject" ,'tr-tech-innovation-dev')     
  .option('project','tr-tech-innovation-dev')
#   .option("credentialsFile", credentials_file)
  .format("bigquery")
  .option("temporaryGcsBucket","tmp-tr-tech-innovation-dev")
  .save("merchant.brands")
)

# %%
res = []

# %%
filters = my_brands.select('category','ranking_country').distinct().collect()

# %%
window = Window.partitionBy("category","ranking_country").orderBy('rank')
my_rank = F.rank().over(window).alias('relative_rank')

# %%
# Out:
# DataFrame[false: boolean]

# %%
final_brands = (my_brands
 .select(my_rank,'brand',"rank","rank_timestamp","category","ranking_country",ranks,F.lit(False).alias('klarna'),F.lit(False).alias('rising'))
 .filter('relative_rank <=30')
 .distinct()
).unionAll(
(my_brands
 .filter('name is not null')
 .select(my_rank,'brand',"rank","rank_timestamp","category","ranking_country",ranks,F.lit(True).alias('klarna'),F.lit(False).alias('rising'))
 .filter('relative_rank <=30')
 .distinct()
)
).unionAll(
(my_brands
    .filter ( (F.col('rank') <     F.col('rank_3w') - 200) 
                & (F.col('rank_1w') <  F.col('rank_2w')) 
                & (F.col('rank_2w') <  F.col('rank_3w')) 
                & (F.col('rank') > 10 ) 
                & (F.col('rank') < 1000 ) )
    .select(my_rank,'brand',"rank","rank_timestamp","category","ranking_country",ranks,F.lit(False).alias('klarna'),F.lit(True).alias('rising'))
 .filter('relative_rank <=30')
 .distinct()
)
)

# %%
final_brands.cache().count()
# Out:
# 458766

# %%
spark._jsc.hadoopConfiguration().set('fs.gs.impl', 'com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem')
# This is required if you are using service account and set true, 
# spark._jsc.hadoopConfiguration().set('fs.gs.auth.service.account.enable', 'true')
# spark._jsc.hadoopConfiguration().set('google.cloud.auth.service.account.json.keyfile', credentials_file)


(final_brands.coalesce(1).write
  .option("parentProject" ,'tr-tech-innovation-dev')     
  .option('project','tr-tech-innovation-dev')
#   .option("credentialsFile", credentials_file)
  .format("bigquery")
  .option("temporaryGcsBucket","tmp-tr-tech-innovation-dev")
  .mode("overwrite")
  .save("merchant.brands_top30")
)

# %%
# +-----------------+---------------+----+------------+
# |all_brands       |ranking_country|rank|ranks       |
# +-----------------+---------------+----+------------+
# |The Ordinary     |US             |1   |1 ◄ 1 ◄ 1   |
# |Philips          |US             |2   |2 ◄ 3 ◄ 3   |
# |Revlon           |US             |3   |4 ◄ 6 ◄ 5   |
# |L'Oréal          |US             |4   |3 ◄ 2 ◄ 2   |
# |Bath & Body Works|US             |5   |5 ◄ 4 ◄ 4   |
# |CeraVe           |US             |6   |6 ◄ 7 ◄ 10  |
# |Eyefusion        |US             |7   |17 ◄ 32 ◄ 62|
# |M·A·C            |US             |8   |7 ◄ 5 ◄ 8   |
# |Lancôme          |US             |9   |13 ◄ 13 ◄ 14|
# |Dior             |US             |10  |8 ◄ 8 ◄ 6   |
# +-----------------+---------------+----+------------+

# %%
# Out:
# 35757

# %%
from itertools import zip_longest

for v in set(cat_matching.keys()): 
    print(v)
    my_brands_str = (my_brands_us
     .filter('name is not null')
     .filter(F.col('category') == v  )
     .groupby(F.col('brand').alias('k_brands'), 'ranking_country')
     .agg(F.min('rank').alias('rank'),ranks )
     .orderBy(F.asc('rank'))
     .limit(10)
    ).show(truncate=False)

    all_brands_str = (my_brands_us
     .filter(F.col('category') == v  )
     .groupby(F.col('brand').alias('all_brands'), 'ranking_country')
     .agg(F.min('rank').alias('rank'),ranks )
     .orderBy(F.asc('rank'))
     .limit(10)
    ).show(truncate=False)

    rising_brands_str = (my_brands_us
#     .filter( (F.col('rank') <  0.9 * F.col('rank_1w')) 
#             &    (F.col('rank_1w') <  0.8 * F.col('rank_2w')) 
#             &    (F.col('rank_2w') < 0.7 * F.col('rank_3w')) 
#               &  (F.col('rank') > 10 ) )
    .filter ( (F.col('rank') <    0.5 * F.col('rank_3w')) 
            &    (F.col('rank_1w') <  F.col('rank_2w')) 
            &    (F.col('rank_2w') <  F.col('rank_3w')) 
              &  (F.col('rank') > 10 ) 
              &  (F.col('rank') < 1000 ) )
                        
     .filter(F.col('category') == v  )
     .groupby(F.col('brand').alias('rising_brands'), 'ranking_country')
     .agg(F.min('rank').alias('rank'),ranks )
     .orderBy(F.asc('rank'))
     .limit(5)
    ).show(truncate=False)
#     for a,b,c in zip_longest(my_brands_str.split('\n'),all_brands_str.split('\n'),rising_brands_str.split('\n')):
#         print(b,'' if not a else a,'' if not c else c)
# Out:
# Health & Beauty > Personal Care
# +-------------+---------------+----+---------------+
# |k_brands     |ranking_country|rank|ranks          |
# +-------------+---------------+----+---------------+
# |Calvin Klein |US             |62  |73 ◄ 74 ◄ 72   |
# |Givenchy     |US             |157 |157 ◄ 151 ◄ 159|
# |Mario Badescu|US             |163 |165 ◄ 160 ◄ 140|
# |SHEIN        |US             |241 |283 ◄ 270 ◄ 259|
# |Beautycounter|US             |270 |203 ◄ 210 ◄ 328|
# |Bio Ionic    |US             |341 |298 ◄ 273 ◄ 292|
# |Perry Ellis  |US             |490 |491 ◄ 448 ◄ 421|
# |Brookstone   |US             |532 |586 ◄ 607 ◄ 600|
# |Nautica      |US             |544 |559 ◄ 561 ◄ 486|
# |Hollister    |US             |567 |629 ◄ 621 ◄ 626|
# +-------------+---------------+----+---------------+
#
# +-----------------+---------------+----+------------+
# |all_brands       |ranking_country|rank|ranks       |
# +-----------------+---------------+----+------------+
# |The Ordinary     |US             |1   |1 ◄ 1 ◄ 1   |
# |Philips          |US             |2   |2 ◄ 3 ◄ 3   |
# |Revlon           |US             |3   |4 ◄ 6 ◄ 5   |
# |L'Oréal          |US             |4   |3 ◄ 2 ◄ 2   |
# |Bath & Body Works|US             |5   |5 ◄ 4 ◄ 4   |
# |CeraVe           |US             |6   |6 ◄ 7 ◄ 10  |
# |Eyefusion        |US             |7   |17 ◄ 32 ◄ 62|
# |M·A·C            |US             |8   |7 ◄ 5 ◄ 8   |
# |Lancôme          |US             |9   |13 ◄ 13 ◄ 14|
# |Dior             |US             |10  |8 ◄ 8 ◄ 6   |
# +-----------------+---------------+----+------------+
#
# +-------------+---------------+----+----------------+
# |rising_brands|ranking_country|rank|ranks           |
# +-------------+---------------+----+----------------+
# |Manscaped    |US             |51  |53 ◄ 54 ◄ 113   |
# |Dr. Jart+    |US             |117 |265 ◄ 282 ◄ 294 |
# |Amscan       |US             |165 |261 ◄ 415 ◄ 629 |
# |Eyekepper    |US             |223 |290 ◄ 474 ◄ 645 |
# |AsWeChange   |US             |290 |303 ◄ 450 ◄ 1032|
# +-------------+---------------+----+----------------+
#
# Home & Garden > Decor
# +------------------+---------------+----+---------------+
# |k_brands          |ranking_country|rank|ranks          |
# +------------------+---------------+----+---------------+
# |iCanvas           |US             |20  |19 ◄ 20 ◄ 20   |
# |SHEIN             |US             |113 |124 ◄ 101 ◄ 96 |
# |Fanatics          |US             |116 |117 ◄ 127 ◄ 122|
# |Swarovski         |US             |180 |182 ◄ 210 ◄ 224|
# |Lenovo            |US             |276 |389 ◄ 442      |
# |H&M               |US             |360 |289 ◄ 337 ◄ 732|
# |Brookstone        |US             |425 |510 ◄ 554 ◄ 493|
# |Yamazaki          |US             |442 |492 ◄ 463 ◄ 450|
# |Inked and Screened|US             |450 |421 ◄ 377 ◄ 406|
# |ROMWE             |US             |732 |716 ◄ 665 ◄ 639|
# +------------------+---------------+----+---------------+
#
# +--------------------+---------------+----+------------+
# |all_brands          |ranking_country|rank|ranks       |
# +--------------------+---------------+----+------------+
# |Pottery Barn        |US             |1   |2 ◄ 2 ◄ 2   |
# |Unique Loom         |US             |2   |3 ◄ 4 ◄ 3   |
# |Safavieh            |US             |3   |1 ◄ 1 ◄ 1   |
# |Threshold           |US             |4   |4 ◄ 3 ◄ 5   |
# |Ashland             |US             |5   |5 ◄ 7 ◄ 4   |
# |nuLOOM              |US             |6   |8 ◄ 6 ◄ 7   |
# |Hyde & EEK! Boutique|US             |7   |6 ◄ 8 ◄ 19  |
# |West Elm            |US             |8   |7 ◄ 5 ◄ 6   |
# |Room Essentials     |US             |9   |9 ◄ 9 ◄ 14  |
# |Hallmark            |US             |10  |10 ◄ 17 ◄ 31|
# +--------------------+---------------+----+------------+
#
# +-------------------+---------------+----+---------------+
# |rising_brands      |ranking_country|rank|ranks          |
# +-------------------+---------------+----+---------------+
# |Wondershop         |US             |50  |71 ◄ 105 ◄ 152 |
# |Old World Christmas|US             |76  |103 ◄ 142 ◄ 174|
# |Holiday Time       |US             |115 |156 ◄ 196 ◄ 291|
# |Williams Sonoma    |US             |125 |119 ◄ 245 ◄ 266|
# |Balsam Hill        |US             |199 |233 ◄ 306 ◄ 418|
# +-------------------+---------------+----+---------------+
#
# Health & Beauty > Health Care
# +------------------+---------------+----+------------------+
# |k_brands          |ranking_country|rank|ranks             |
# +------------------+---------------+----+------------------+
# |Love Wellness     |US             |24  |24 ◄ 22 ◄ 20      |
# |Roman             |US             |67  |72 ◄ 80 ◄ 79      |
# |SHEIN             |US             |628 |703 ◄ 737 ◄ 744   |
# |adidas            |US             |1080|1104 ◄ 990 ◄ 883  |
# |Hollister         |US             |1149|1156 ◄ 1244 ◄ 1182|
# |Burton            |US             |1383|1438 ◄ 1448 ◄ 1401|
# |Iron Bull Strength|US             |2168|2190 ◄ 2109 ◄ 2145|
# +------------------+---------------+----+------------------+
#
# +--------------------------+---------------+----+------------+
# |all_brands                |ranking_country|rank|ranks       |
# +--------------------------+---------------+----+------------+
# |Fitbit                    |US             |1   |1 ◄ 1 ◄ 1   |
# |NOW                       |US             |2   |3 ◄ 4 ◄ 4   |
# |Nature Made               |US             |3   |2 ◄ 2 ◄ 2   |
# |Puritan's Pride           |US             |4   |4 ◄ 3 ◄ 3   |
# |Spring Valley             |US             |5   |6 ◄ 6 ◄ 8   |
# |Drive DeVilbiss Healthcare|US             |6   |5 ◄ 5 ◄ 5   |
# |Garmin                    |US             |7   |10 ◄ 15 ◄ 14|
# |Hum Nutrition             |US             |8   |7 ◄ 12 ◄ 6  |
# |GNC                       |US             |9   |8 ◄ 9 ◄ 12  |
# |Nature's Way              |US             |10  |9 ◄ 7 ◄ 9   |
# +--------------------------+---------------+----+------------+
#
# +-------------+---------------+----+---------------+
# |rising_brands|ranking_country|rank|ranks          |
# +-------------+---------------+----+---------------+
# |Sanitec      |US             |63  |98 ◄ 123 ◄ 134 |
# |EldonCard    |US             |76  |167 ◄ 847 ◄ 977|
# |Mommy's Bliss|US             |79  |88 ◄ 120 ◄ 181 |
# |Eu Natural   |US             |88  |119 ◄ 149 ◄ 256|
# |Verilux      |US             |178 |261 ◄ 373 ◄ 416|
# +-------------+---------------+----+---------------+
#
# Furniture
# +--------------+---------------+----+------------------+
# |k_brands      |ranking_country|rank|ranks             |
# +--------------+---------------+----+------------------+
# |Macy's        |US             |57  |56 ◄ 57 ◄ 63      |
# |Rove Concepts |US             |99  |100 ◄ 99 ◄ 96     |
# |Saatva        |US             |180 |195 ◄ 188 ◄ 186   |
# |Kardiel       |US             |247 |255 ◄ 272 ◄ 283   |
# |Yamazaki      |US             |262 |310 ◄ 345 ◄ 273   |
# |PlushBeds     |US             |352 |354 ◄ 384 ◄ 395   |
# |Tommy Hilfiger|US             |757 |728 ◄ 722 ◄ 655   |
# |Helix Sleep   |US             |872 |938 ◄ 938 ◄ 881   |
# |Fender        |US             |1183|1117 ◄ 1307 ◄ 1269|
# |iCanvas       |US             |1199|1229 ◄ 1135 ◄ 1110|
# +--------------+---------------+----+------------------+
#
# +-------------------------------+---------------+----+------------+
# |all_brands                     |ranking_country|rank|ranks       |
# +-------------------------------+---------------+----+------------+
# |Ebern Designs                  |US             |1   |1 ◄ 1 ◄ 2   |
# |Latitude Run                   |US             |2   |2 ◄ 2 ◄ 3   |
# |Andover Mills                  |US             |3   |3 ◄ 3 ◄ 4   |
# |Three Posts                    |US             |4   |4 ◄ 5 ◄ 5   |
# |Wayfair                        |US             |5   |6 ◄ 6 ◄ 6   |
# |Red Barrel Studio              |US             |6   |5 ◄ 7 ◄ 7   |
# |Pottery Barn                   |US             |7   |7 ◄ 9 ◄ 9   |
# |Ashley HomeStore               |US             |8   |8 ◄ 4 ◄ 1   |
# |Mercury Row                    |US             |9   |10 ◄ 10 ◄ 10|
# |Laurel Foundry Modern Farmhouse|US             |10  |11 ◄ 11 ◄ 8 |
# +-------------------------------+---------------+----+------------+
#
# +-----------------+---------------+----+------------------+
# |rising_brands    |ranking_country|rank|ranks             |
# +-----------------+---------------+----+------------------+
# |Calicosy         |US             |205 |208 ◄ 214 ◄ 752   |
# |Mickey Mouse     |US             |336 |371 ◄ 512 ◄ 709   |
# |tulo             |US             |370 |502 ◄ 666 ◄ 848   |
# |Animal Adventure |US             |785 |1454 ◄ 1522 ◄ 1638|
# |Hi-Line Gift Ltd.|US             |907 |1189 ◄ 1684 ◄ 1885|
# +-----------------+---------------+----+------------------+
#
# Apparel & Accessories > Jewelry
# +---------+---------------+----+---------------+
# |k_brands |ranking_country|rank|ranks          |
# +---------+---------------+----+---------------+
# |SHEIN    |US             |4   |4 ◄ 4 ◄ 4      |
# |Swarovski|US             |11  |12 ◄ 14 ◄ 23   |
# |ROMWE    |US             |12  |13 ◄ 11 ◄ 9    |
# |Mejuri   |US             |23  |29 ◄ 27 ◄ 25   |
# |Macy's   |US             |33  |34 ◄ 18 ◄ 30   |
# |ASOS     |US             |75  |71 ◄ 60 ◄ 64   |
# |Lulus    |US             |80  |78 ◄ 76 ◄ 76   |
# |Rastaclat|US             |93  |106 ◄ 88 ◄ 87  |
# |Hot Topic|US             |122 |154 ◄ 214 ◄ 208|
# |Diesel   |US             |129 |114 ◄ 125 ◄ 115|
# +---------+---------------+----+---------------+
#
# +------------+---------------+----+------------+
# |all_brands  |ranking_country|rank|ranks       |
# +------------+---------------+----+------------+
# |Apple       |US             |1   |1 ◄ 1 ◄ 1   |
# |Zales       |US             |2   |2 ◄ 3 ◄ 3   |
# |PANDORA     |US             |3   |3 ◄ 2 ◄ 2   |
# |SHEIN       |US             |4   |4 ◄ 4 ◄ 4   |
# |Kay Jewelers|US             |5   |5 ◄ 5 ◄ 5   |
# |Casio       |US             |6   |6 ◄ 7 ◄ 6   |
# |Body Candy  |US             |7   |7 ◄ 6 ◄ 7   |
# |Kendra Scott|US             |8   |8 ◄ 9 ◄ 8   |
# |Samsung     |US             |9   |10 ◄ 12 ◄ 12|
# |Fossil      |US             |10  |9 ◄ 8 ◄ 10  |
# +------------+---------------+----+------------+
#
# +-------------+---------------+----+---------------+
# |rising_brands|ranking_country|rank|ranks          |
# +-------------+---------------+----+---------------+
# |Swarovski    |US             |11  |12 ◄ 14 ◄ 23   |
# |Blue Nile    |US             |50  |54 ◄ 75 ◄ 126  |
# |Sundance     |US             |102 |152 ◄ 186 ◄ 220|
# |Amscan       |US             |107 |131 ◄ 169 ◄ 238|
# |S&P JEWELRY  |US             |157 |226 ◄ 388 ◄ 495|
# +-------------+---------------+----+---------------+
#
# Sporting Goods
# +--------------+---------------+----+---------------+
# |k_brands      |ranking_country|rank|ranks          |
# +--------------+---------------+----+---------------+
# |TaylorMade    |US             |24  |18 ◄ 14 ◄ 14   |
# |Burton        |US             |31  |43 ◄ 55 ◄ 60   |
# |adidas        |US             |37  |35 ◄ 31 ◄ 25   |
# |Jetson        |US             |55  |60 ◄ 69 ◄ 80   |
# |The North Face|US             |138 |135 ◄ 137 ◄ 124|
# |Leatherman    |US             |143 |162 ◄ 157 ◄ 173|
# |Black Crows   |US             |480 |553 ◄ 686 ◄ 769|
# |Gymshark      |US             |489 |341 ◄ 376 ◄ 437|
# |Reebok        |US             |688 |708 ◄ 805 ◄ 845|
# |Fanatics      |US             |713 |699 ◄ 530 ◄ 569|
# +--------------+---------------+----+---------------+
#
# +-------------+---------------+----+-------------+
# |all_brands   |ranking_country|rank|ranks        |
# +-------------+---------------+----+-------------+
# |Shimano      |US             |1   |1 ◄ 1 ◄ 1    |
# |Schwinn      |US             |2   |2 ◄ 2 ◄ 2    |
# |CAP Barbell  |US             |3   |4 ◄ 4 ◄ 7    |
# |Rogue Fitness|US             |4   |3 ◄ 3 ◄ 3    |
# |Intex        |US             |5   |6 ◄ 6 ◄ 6    |
# |Wilson       |US             |6   |8 ◄ 8 ◄ 5    |
# |Nike         |US             |7   |7 ◄ 5 ◄ 4    |
# |Huffy        |US             |8   |479 ◄ 5 ◄ 406|
# |Razor        |US             |9   |9 ◄ 12 ◄ 13  |
# |Callaway     |US             |10  |13 ◄ 9 ◄ 10  |
# +-------------+---------------+----+-------------+
#
# +-----------------------+---------------+----+-----------------+
# |rising_brands          |ranking_country|rank|ranks            |
# +-----------------------+---------------+----+-----------------+
# |Bowflex                |US             |14  |31 ◄ 47 ◄ 55     |
# |Titan Fitness          |US             |64  |69 ◄ 107 ◄ 208   |
# |Nishiki                |US             |113 |124 ◄ 281 ◄ 728  |
# |HotHands               |US             |120 |191 ◄ 228 ◄ 243  |
# |Fabrication Enterprises|US             |134 |109 ◄ 2294 ◄ 2830|
# +-----------------------+---------------+----+-----------------+
#
# Home & Garden > Linens & Bedding
# +--------------+---------------+----+---------------+
# |k_brands      |ranking_country|rank|ranks          |
# +--------------+---------------+----+---------------+
# |Nautica       |US             |64  |78 ◄ 64 ◄ 75   |
# |Fanatics      |US             |81  |91 ◄ 102 ◄ 100 |
# |SHEIN         |US             |83  |112 ◄ 80 ◄ 79  |
# |Brookstone    |US             |104 |118 ◄ 92 ◄ 86  |
# |IZOD          |US             |152 |156 ◄ 177 ◄ 177|
# |Calvin Klein  |US             |170 |173 ◄ 164 ◄ 169|
# |Tommy Hilfiger|US             |180 |162 ◄ 194 ◄ 194|
# |H&M           |US             |226 |151 ◄ 157 ◄ 200|
# |Ted Baker     |US             |272 |274 ◄ 290 ◄ 277|
# |Perry Ellis   |US             |373 |531 ◄ 489 ◄ 509|
# +--------------+---------------+----+---------------+
#
# +-----------------+---------------+----+------------+
# |all_brands       |ranking_country|rank|ranks       |
# +-----------------+---------------+----+------------+
# |Pottery Barn     |US             |1   |1 ◄ 1 ◄ 1   |
# |Madison Park     |US             |2   |2 ◄ 2 ◄ 2   |
# |Threshold        |US             |3   |3 ◄ 5 ◄ 5   |
# |The Company Store|US             |4   |5 ◄ 4 ◄ 3   |
# |The Big One      |US             |5   |6 ◄ 8 ◄ 8   |
# |West Elm         |US             |6   |4 ◄ 3 ◄ 4   |
# |Mainstays        |US             |7   |8 ◄ 6 ◄ 6   |
# |Room Essentials  |US             |8   |7 ◄ 7 ◄ 7   |
# |the Comfy        |US             |9   |11 ◄ 12 ◄ 15|
# |Eddie Bauer      |US             |10  |10 ◄ 10 ◄ 13|
# +-----------------+---------------+----+------------+
#
# +-------------+---------------+----+---------------+
# |rising_brands|ranking_country|rank|ranks          |
# +-------------+---------------+----+---------------+
# |Amscan       |US             |21  |22 ◄ 31 ◄ 49   |
# |Biddeford    |US             |39  |62 ◄ 71 ◄ 83   |
# |St. Nicholas |US             |231 |312 ◄ 435 ◄ 581|
# |Country Door |US             |317 |324 ◄ 386 ◄ 660|
# |Celine Linen |US             |339 |406 ◄ 614 ◄ 994|
# +-------------+---------------+----+---------------+
#
# Electronics > Audio
# +----------------+---------------+----+---------------+
# |k_brands        |ranking_country|rank|ranks          |
# +----------------+---------------+----+---------------+
# |Bose            |US             |2   |2 ◄ 2 ◄ 2      |
# |JBL             |US             |3   |3 ◄ 3 ◄ 4      |
# |Sonos           |US             |29  |28 ◄ 31 ◄ 28   |
# |SHEIN           |US             |58  |61 ◄ 61 ◄ 60   |
# |Case-Mate       |US             |132 |192 ◄ 318      |
# |Master & Dynamic|US             |160 |139 ◄ 157 ◄ 160|
# |Fender          |US             |195 |206 ◄ 186 ◄ 174|
# |V-MODA          |US             |235 |229 ◄ 200 ◄ 184|
# |CASETiFY        |US             |260 |289 ◄ 309 ◄ 292|
# |Lenovo          |US             |264 |263 ◄ 148 ◄ 142|
# +----------------+---------------+----+---------------+
#
# +------------+---------------+----+-----------+
# |all_brands  |ranking_country|rank|ranks      |
# +------------+---------------+----+-----------+
# |Apple       |US             |1   |1 ◄ 1 ◄ 1  |
# |Bose        |US             |2   |2 ◄ 2 ◄ 2  |
# |JBL         |US             |3   |3 ◄ 3 ◄ 4  |
# |Beats       |US             |4   |5 ◄ 5 ◄ 5  |
# |Sony        |US             |5   |4 ◄ 4 ◄ 3  |
# |Google      |US             |6   |6 ◄ 6 ◄ 9  |
# |Amazon      |US             |7   |8 ◄ 10 ◄ 10|
# |Samsung     |US             |8   |7 ◄ 8 ◄ 7  |
# |Logitech    |US             |9   |9 ◄ 7 ◄ 6  |
# |Turtle Beach|US             |10  |10 ◄ 9 ◄ 8 |
# +------------+---------------+----+-----------+
#
# +-------------+---------------+----+---------------+
# |rising_brands|ranking_country|rank|ranks          |
# +-------------+---------------+----+---------------+
# |Amscan       |US             |142 |164 ◄ 246 ◄ 307|
# |Cellet       |US             |155 |189 ◄ 228 ◄ 319|
# |RUIZU        |US             |221 |298 ◄ 565 ◄ 625|
# |Kustom       |US             |332 |362 ◄ 634 ◄ 717|
# +-------------+---------------+----+---------------+
#
# Toys & Games
# +----------+---------------+----+------------------+
# |k_brands  |ranking_country|rank|ranks             |
# +----------+---------------+----+------------------+
# |Dynamite  |US             |406 |367 ◄ 356 ◄ 365   |
# |Fanatics  |US             |896 |975 ◄ 1084 ◄ 1046 |
# |Hot Topic |US             |1252|1293 ◄ 1403 ◄ 1456|
# |Lume Cube |US             |1426|1236 ◄ 1247 ◄ 1245|
# |Brookstone|US             |1884|2003 ◄ 1837 ◄ 1775|
# |Blast Zone|US             |1983|1755 ◄ 1612 ◄ 1398|
# |Nautica   |US             |2230|1959 ◄ 1901 ◄ 2135|
# +----------+---------------+----+------------------+
#
# +----------------+---------------+----+------------+
# |all_brands      |ranking_country|rank|ranks       |
# +----------------+---------------+----+------------+
# |LEGO            |US             |1   |1 ◄ 1 ◄ 1   |
# |Hasbro          |US             |2   |2 ◄ 2 ◄ 2   |
# |Funko           |US             |3   |3 ◄ 3 ◄ 3   |
# |Mattel          |US             |4   |4 ◄ 4 ◄ 4   |
# |Disney          |US             |5   |5 ◄ 5 ◄ 5   |
# |Spin Master     |US             |6   |7 ◄ 7 ◄ 8   |
# |Little Tikes    |US             |7   |6 ◄ 6 ◄ 6   |
# |Fisher-Price    |US             |8   |8 ◄ 9 ◄ 9   |
# |L.O.L. Surprise!|US             |9   |9 ◄ 8 ◄ 7   |
# |Melissa & Doug  |US             |10  |10 ◄ 11 ◄ 10|
# +----------------+---------------+----+------------+
#
# +--------------------+---------------+----+---------------+
# |rising_brands       |ranking_country|rank|ranks          |
# +--------------------+---------------+----+---------------+
# |Little Live Pets    |US             |33  |33 ◄ 51 ◄ 79   |
# |Epic Games          |US             |79  |89 ◄ 137 ◄ 172 |
# |Fun Wheels          |US             |324 |365 ◄ 612 ◄ 721|
# |FAO Schwarz         |US             |342 |450 ◄ 623 ◄ 705|
# |Home Accents Holiday|US             |376 |786 ◄ 788 ◄ 998|
# +--------------------+---------------+----+---------------+
#
# Apparel & Accessories > Clothing
# +-----------------+---------------+----+------------+
# |k_brands         |ranking_country|rank|ranks       |
# +-----------------+---------------+----+------------+
# |SHEIN            |US             |3   |3 ◄ 3 ◄ 3   |
# |The North Face   |US             |7   |7 ◄ 7 ◄ 8   |
# |adidas           |US             |10  |9 ◄ 8 ◄ 7   |
# |Fanatics         |US             |12  |16 ◄ 17 ◄ 13|
# |ROMWE            |US             |13  |11 ◄ 12 ◄ 12|
# |PrettyLittleThing|US             |22  |21 ◄ 24 ◄ 26|
# |ASOS             |US             |27  |25 ◄ 22 ◄ 22|
# |Boohoo           |US             |38  |32 ◄ 33 ◄ 37|
# |Missguided       |US             |42  |36 ◄ 36 ◄ 42|
# |Hollister        |US             |50  |49 ◄ 42 ◄ 40|
# +-----------------+---------------+----+------------+
#
# +---------------+---------------+----+------------+
# |all_brands     |ranking_country|rank|ranks       |
# +---------------+---------------+----+------------+
# |Nike           |US             |1   |1 ◄ 1 ◄ 1   |
# |Old Navy       |US             |2   |2 ◄ 2 ◄ 2   |
# |SHEIN          |US             |3   |3 ◄ 3 ◄ 3   |
# |Gap            |US             |4   |4 ◄ 4 ◄ 4   |
# |Banana Republic|US             |5   |5 ◄ 5 ◄ 6   |
# |Carter's       |US             |6   |6 ◄ 6 ◄ 5   |
# |The North Face |US             |7   |7 ◄ 7 ◄ 8   |
# |Lands' End     |US             |8   |13 ◄ 13 ◄ 14|
# |Cat & Jack     |US             |9   |8 ◄ 10 ◄ 18 |
# |adidas         |US             |10  |9 ◄ 8 ◄ 7   |
# +---------------+---------------+----+------------+
#
# +-------------------------+---------------+----+---------------+
# |rising_brands            |ranking_country|rank|ranks          |
# +-------------------------+---------------+----+---------------+
# |Amscan                   |US             |77  |98 ◄ 167 ◄ 288 |
# |Zara                     |US             |80  |57 ◄ 124 ◄ 282 |
# |Avenue                   |US             |203 |260 ◄ 304 ◄ 414|
# |Warner Bros.             |US             |210 |320 ◄ 448 ◄ 537|
# |Jammies For Your Families|US             |247 |313 ◄ 460 ◄ 571|
# +-------------------------+---------------+----+---------------+
#
# Apparel & Accessories > Shoes
# +--------------+---------------+----+------------+
# |k_brands      |ranking_country|rank|ranks       |
# +--------------+---------------+----+------------+
# |adidas        |US             |2   |2 ◄ 2 ◄ 2   |
# |Timberland    |US             |12  |12 ◄ 12 ◄ 15|
# |Reebok        |US             |18  |17 ◄ 17 ◄ 17|
# |Clarks        |US             |21  |20 ◄ 20 ◄ 18|
# |The North Face|US             |35  |56 ◄ 53 ◄ 54|
# |SHEIN         |US             |36  |45 ◄ 38 ◄ 41|
# |TOMS          |US             |38  |33 ◄ 33 ◄ 29|
# |Lulus         |US             |52  |38 ◄ 44 ◄ 45|
# |ASOS          |US             |54  |51 ◄ 50 ◄ 53|
# |Danner        |US             |64  |64 ◄ 63 ◄ 60|
# +--------------+---------------+----+------------+
#
# +-----------+---------------+----+------------+
# |all_brands |ranking_country|rank|ranks       |
# +-----------+---------------+----+------------+
# |Nike       |US             |1   |1 ◄ 1 ◄ 1   |
# |adidas     |US             |2   |2 ◄ 2 ◄ 2   |
# |UGG        |US             |3   |4 ◄ 4 ◄ 4   |
# |Vans       |US             |4   |3 ◄ 3 ◄ 3   |
# |Converse   |US             |5   |5 ◄ 5 ◄ 5   |
# |New Balance|US             |6   |6 ◄ 6 ◄ 6   |
# |Crocs      |US             |7   |7 ◄ 7 ◄ 7   |
# |SKECHERS   |US             |8   |8 ◄ 8 ◄ 8   |
# |PUMA       |US             |9   |9 ◄ 9 ◄ 9   |
# |Dr. Martens|US             |10  |11 ◄ 11 ◄ 11|
# +-----------+---------------+----+------------+
#
# +----------------+---------------+----+----------------+
# |rising_brands   |ranking_country|rank|ranks           |
# +----------------+---------------+----+----------------+
# |Universal Thread|US             |39  |53 ◄ 61 ◄ 82    |
# |JustFab         |US             |177 |421 ◄ 554 ◄ 640 |
# |Rubie's         |US             |291 |390 ◄ 504 ◄ 607 |
# |Two24           |US             |375 |466 ◄ 748 ◄ 1839|
# |Gianni Bini     |US             |442 |565 ◄ 821 ◄ 1109|
# +----------------+---------------+----+----------------+
#
# Luggage & Bags
# +--------------+---------------+----+---------------+
# |k_brands      |ranking_country|rank|ranks          |
# +--------------+---------------+----+---------------+
# |The North Face|US             |3   |4 ◄ 2 ◄ 2      |
# |adidas        |US             |7   |7 ◄ 8 ◄ 7      |
# |JanSport      |US             |11  |10 ◄ 7 ◄ 5     |
# |SHEIN         |US             |21  |25 ◄ 20 ◄ 24   |
# |Eagle Creek   |US             |73  |72 ◄ 68 ◄ 55   |
# |ROMWE         |US             |99  |93 ◄ 86 ◄ 88   |
# |MCM           |US             |126 |134 ◄ 134 ◄ 130|
# |Ted Baker     |US             |135 |145 ◄ 138 ◄ 146|
# |Tommy Hilfiger|US             |143 |135 ◄ 139 ◄ 145|
# |RIMOWA        |US             |146 |138 ◄ 147 ◄ 161|
# +--------------+---------------+----+---------------+
#
# +-------------------+---------------+----+------------+
# |all_brands         |ranking_country|rank|ranks       |
# +-------------------+---------------+----+------------+
# |Nike               |US             |1   |1 ◄ 1 ◄ 1   |
# |COACH              |US             |2   |2 ◄ 3 ◄ 6   |
# |The North Face     |US             |3   |4 ◄ 2 ◄ 2   |
# |Samsonite          |US             |4   |3 ◄ 5 ◄ 8   |
# |Pottery Barn       |US             |5   |5 ◄ 4 ◄ 3   |
# |Herschel Supply Co.|US             |6   |6 ◄ 6 ◄ 4   |
# |adidas             |US             |7   |7 ◄ 8 ◄ 7   |
# |Patagonia          |US             |8   |8 ◄ 11 ◄ 14 |
# |Vera Bradley       |US             |9   |9 ◄ 9 ◄ 9   |
# |Osprey             |US             |10  |11 ◄ 12 ◄ 11|
# +-------------------+---------------+----+------------+
#
# +-------------+---------------+----+---------------+
# |rising_brands|ranking_country|rank|ranks          |
# +-------------+---------------+----+---------------+
# |Sonia Kashuk |US             |56  |57 ◄ 87 ◄ 123  |
# |Everlane     |US             |57  |73 ◄ 118 ◄ 142 |
# |Missguided   |US             |177 |163 ◄ 188 ◄ 792|
# |Amscan       |US             |181 |199 ◄ 290 ◄ 391|
# |Explorer     |US             |212 |287 ◄ 477 ◄ 812|
# +-------------+---------------+----+---------------+
#
# Home & Garden > Kitchen & Dining
# +-----------+---------------+----+------------------+
# |k_brands   |ranking_country|rank|ranks             |
# +-----------+---------------+----+------------------+
# |Fanatics   |US             |156 |153 ◄ 156 ◄ 150   |
# |SHEIN      |US             |182 |236 ◄ 218 ◄ 206   |
# |Yamazaki   |US             |229 |1929 ◄ 2068 ◄ 233 |
# |Dalstrong  |US             |251 |247 ◄ 240 ◄ 248   |
# |adidas     |US             |576 |572 ◄ 532 ◄ 517   |
# |Brookstone |US             |851 |927 ◄ 930 ◄ 904   |
# |H&M        |US             |1248|1186 ◄ 2444 ◄ 1453|
# |Reebok     |US             |1264|1080 ◄ 1039 ◄ 1158|
# |JanSport   |US             |1313|1058 ◄ 912 ◄ 793  |
# |Perry Ellis|US             |2154|1381 ◄ 1294       |
# +-----------+---------------+----+------------------+
#
# +----------------+---------------+----+------------+
# |all_brands      |ranking_country|rank|ranks       |
# +----------------+---------------+----+------------+
# |Cuisinart       |US             |1   |2 ◄ 1 ◄ 1   |
# |KitchenAid      |US             |2   |1 ◄ 2 ◄ 2   |
# |Ninja           |US             |3   |5 ◄ 7 ◄ 7   |
# |Frigidaire      |US             |4   |3 ◄ 3 ◄ 3   |
# |GE              |US             |5   |6 ◄ 5 ◄ 6   |
# |Whirlpool       |US             |6   |4 ◄ 4 ◄ 4   |
# |YETI            |US             |7   |7 ◄ 6 ◄ 5   |
# |Keurig          |US             |8   |9 ◄ 8 ◄ 8   |
# |Crate and Barrel|US             |9   |8 ◄ 9 ◄ 11  |
# |Hamilton Beach  |US             |10  |10 ◄ 10 ◄ 10|
# +----------------+---------------+----+------------+
#
# +---------------+---------------+----+---------------+
# |rising_brands  |ranking_country|rank|ranks          |
# +---------------+---------------+----+---------------+
# |Williams Sonoma|US             |21  |22 ◄ 36 ◄ 48   |
# |Instant Pot    |US             |22  |21 ◄ 32 ◄ 47   |
# |Amscan         |US             |33  |36 ◄ 47 ◄ 71   |
# |Simple Modern  |US             |105 |141 ◄ 220 ◄ 221|
# |Kirkland's     |US             |223 |268 ◄ 417 ◄ 476|
# +---------------+---------------+----+---------------+

# %%
# Out:
# +--------------------+---------------+----+------------------+
# |       rising_brands|ranking_country|rank|             ranks|
# +--------------------+---------------+----+------------------+
# |    Little Live Pets|             US|  33|      33 ◄ 51 ◄ 79|
# |          Epic Games|             US|  79|    89 ◄ 137 ◄ 172|
# |          Fun Wheels|             US| 324|   365 ◄ 612 ◄ 721|
# |         FAO Schwarz|             US| 342|   450 ◄ 623 ◄ 705|
# |Home Accents Holiday|             US| 376|   786 ◄ 788 ◄ 998|
# |          HCM Kinzel|             US| 381|  372 ◄ 404 ◄ 1047|
# |Magformers (Магфо...|             US| 455| 823 ◄ 1105 ◄ 1411|
# |               Topps|             US| 545|  548 ◄ 846 ◄ 1114|
# |                 TCG|             US| 559|1370 ◄ 1401 ◄ 1467|
# |             Lortone|             US| 568|  571 ◄ 760 ◄ 1184|
# +--------------------+---------------+----+------------------+

# %%
topProducts4weeks = (reader
  .option('table', 'BestSellers_TopProducts_8090258')
  .option('filter', '_PARTITIONDATE in ("2020-10-05","2020-10-12","2020-10-19","2020-10-26")')
  .load()
)

from pyspark.storagelevel import StorageLevel
# topBrands4weeks.persist(StorageLevel.DISK_ONLY).count()
topProducts4weeks.cache().count()
# Out:
# 20363021

# %%
topProducts4weeks.write.parquet(f'gs://{bucket}/klarna/topProducts4weeks.parquet')

# %%
window2 = Window.partitionBy("product.name","brand","category","ranking_country").orderBy('rank_timestamp')
plast_w1 = F.lag('rank',1).over(window2).alias('rank_1w')
plast_w2 = F.lag('rank',2).over(window2).alias('rank_2w')
plast_w3 = F.lag('rank',3).over(window2).alias('rank_3w')

products = (topProducts4weeks
          .select('*', 
                    F.explode('ranking_category_path').alias('cat')
            )
            .filter('cat.locale = "en-US"')
             .drop('ranking_category_path')          
          .select('rank','brand','ranking_country','rank_timestamp',
                  'ranking_category',F.col('cat.name').alias('category'), col2,
                 'price_range',F.explode('product_title').alias('product'))
          
            .filter('product.locale = "en-US"')
          .select('*', plast_w1,plast_w2,plast_w3)
          .filter(F.col('rank_timestamp') == max_timestamp )
         )

# %%
products = products.drop("name")

# %%
my_products = products.join(klarna_merchants,klarna_merchants.name == products.brand,'leftOuter')
my_products.cache().count()
# Out:
# 1399598

# %%
# Out:
# DataFrame[rank: bigint, brand: string, ranking_country: string, rank_timestamp: timestamp, ranking_category: bigint, category: string, my_cat: string, price_range: struct<min:decimal(38,9),max:decimal(38,9),currency:string>, product: struct<locale:string,name:string>, rank_1w: bigint, rank_2w: bigint, rank_3w: bigint]

# %%
products = spark.read.parquet(f'gs://{bucket}/klarna/my_products_fullCategories.parquet')

# %%
# !gsutil -m rm -r 'gs://{bucket}/klarna/my_products_fullCategories.parquet'

# %%
my_products.write.parquet(f'gs://{bucket}/klarna/my_products_fullCategories.parquet')

# %%
my_products_us = my_products.where('ranking_country = "US" ')

# %%
pranks = (F.concat_ws(' ◄ ','rank_1w','rank_2w', 'rank_3w')).alias('ranks')

# %%
my_products_us.withColumn('ranks',pranks)
# Out:
# DataFrame[rank: bigint, brand: string, ranking_country: string, rank_timestamp: timestamp, ranking_category: bigint, category: string, my_cat: string, price_range: struct<min:decimal(38,9),max:decimal(38,9),currency:string>, product: struct<locale:string,name:string>, rank_1w: bigint, rank_2w: bigint, rank_3w: bigint, position: bigint, target: string, name: string, ranks: string]

# %%
window = Window.partitionBy("category","ranking_country").orderBy('rank')
my_rank = F.rank().over(window).alias('relative_rank')

# %%
final_products = (my_products_us
 .select(my_rank,'brand','product.name' ,"rank","rank_timestamp","category","ranking_country",ranks,F.lit(False).alias('klarna'),F.lit(False).alias('rising'))
 .filter('relative_rank <=30')
 .distinct()
).unionAll(
(my_products_us
 .filter('name is not null')
 .select(my_rank,'brand','product.name' ,"rank","rank_timestamp","category","ranking_country",ranks,F.lit(True).alias('klarna'),F.lit(False).alias('rising'))
 .filter('relative_rank <=30')
 .distinct()
)
).unionAll(
(my_products_us
    .filter ( (F.col('rank') <     F.col('rank_3w') - 200) 
                & (F.col('rank_1w') <  F.col('rank_2w')) 
                & (F.col('rank_2w') <  F.col('rank_3w')) 
                & (F.col('rank') > 10 ) 
                & (F.col('rank') < 1000 ) )
    .select(my_rank,'brand','product.name' ,"rank","rank_timestamp","category","ranking_country",ranks,F.lit(False).alias('klarna'),F.lit(True).alias('rising'))
 .filter('relative_rank <=30')
 .distinct()
)
)

# %%
final_products.cache().count()
# Out:
# 113068

# %%
spark._jsc.hadoopConfiguration().set('fs.gs.impl', 'com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem')
# This is required if you are using service account and set true, 
# spark._jsc.hadoopConfiguration().set('fs.gs.auth.service.account.enable', 'true')
# spark._jsc.hadoopConfiguration().set('google.cloud.auth.service.account.json.keyfile', credentials_file)


(final_products.coalesce(1).write
  .option("parentProject" ,'tr-tech-innovation-dev')     
  .option('project','tr-tech-innovation-dev')
#   .option("credentialsFile", credentials_file)
  .format("bigquery")
  .option("temporaryGcsBucket","tmp-tr-tech-innovation-dev")
  .mode("overwrite")
  .save("merchant.products_top30")
)

# %%
(final_products
 .filter('klarna')
 .filter('category = "Electronics > Audio" ')
 .filter('ranking_country = "US"')
 .select('brand','name','ranking_country','rank','ranks'   )
 .orderBy('rank')
).show()
# Out:
# +-----+--------------------+---------------+----+---------------+
# |brand|                name|ranking_country|rank|          ranks|
# +-----+--------------------+---------------+----+---------------+
# | Bose|Bose QuietComfort...|             US|   4|    4 ◄ 61 ◄ 77|
# |  JBL|          JBL Flip 5|             US|   9|    7 ◄ 11 ◄ 17|
# | Bose|  Bose Sport Earbuds|             US|  21|               |
# |  JBL|        JBL Charge 4|             US|  23|   19 ◄ 20 ◄ 49|
# | Bose|Bose QuietComfort...|             US|  24|        18 ◄ 17|
# | Bose|Bose SoundLink Re...|             US|  28| 30 ◄ 202 ◄ 189|
# |  JBL|          JBL Clip 3|             US|  33|   34 ◄ 29 ◄ 72|
# | Bose|Bose SoundLink Co...|             US|  41|   41 ◄ 62 ◄ 60|
# | Bose|         Bose Solo 5|             US|  50|   64 ◄ 84 ◄ 85|
# | Bose|Bose SoundSport W...|             US|  62|   69 ◄ 66 ◄ 98|
# |  JBL|      JBL TUNE 500BT|             US|  65| 78 ◄ 114 ◄ 279|
# | Bose|Bose QuietComfort...|             US|  70|             88|
# |  JBL|            JBL Go 2|             US|  80|111 ◄ 263 ◄ 154|
# |  JBL|    JBL PartyBox 100|             US|  81|208 ◄ 153 ◄ 252|
# | Bose|Bose SoundLink Micro|             US|  82|  97 ◄ 108 ◄ 83|
# |  JBL|     JBL TUNE 120TWS|             US|  83|184 ◄ 644 ◄ 333|
# |Sonos|           Sonos Arc|             US|  84|   90 ◄ 89 ◄ 86|
# |  JBL|JBL Endurance Spr...|             US|  99|  102 ◄ 95 ◄ 70|
# | Bose|Bose SoundLink Ar...|             US| 114|179 ◄ 170 ◄ 165|
# |  JBL|         JBL Bar 5.1|             US| 115| 93 ◄ 477 ◄ 731|
# +-----+--------------------+---------------+----+---------------+
# only showing top 20 rows

# %%
spark._jsc.hadoopConfiguration().set('fs.gs.impl', 'com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem')
# This is required if you are using service account and set true, 
# spark._jsc.hadoopConfiguration().set('fs.gs.auth.service.account.enable', 'true')
# spark._jsc.hadoopConfiguration().set('google.cloud.auth.service.account.json.keyfile', credentials_file)


(my_products_us.withColumn('ranks',pranks).coalesce(1).write
  .option("parentProject" ,'tr-tech-innovation-dev')     
  .option('project','tr-tech-innovation-dev')
#   .option("credentialsFile", credentials_file)
  .format("bigquery")
  .option("temporaryGcsBucket","tmp-tr-tech-innovation-dev")
  .save("merchant.products")
)

# %%
my_products_us.cache().count()
# Out:
# 1375890

# %%
my_products_us.head()
# Out:
# Row(rank=2386, brand='ASTRO', ranking_country='US', rank_timestamp=datetime.datetime(2020, 10, 23, 0, 0), ranking_category=223, category='Electronics > Audio', my_cat='Electronics', price_range=Row(min=Decimal('60.000000000'), max=Decimal('60.000000000'), currency='USD'), product=Row(locale='en-US', name='Astro Gaming A40 TR Mod Kit'), rank_1w=2620, rank_2w=5031, rank_3w=None, position=None, target=None, name=None)

# %%
    my_brands_str = (my_products_us
     .filter('name is not null')
     .filter(F.col('category') == v  )
     .groupby(F.col('brand').alias('klarna'),'product.name' ,'ranking_country')
     .agg(F.min('rank').alias('rank'),ranks )
     .orderBy(F.asc('rank'))
     .limit(10)
    ).show(truncate=False)

# %%
from itertools import zip_longest

for v in set(cat_matching.keys()): 
    print(v)
    my_brands_str = (my_products_us
     .filter('name is not null')
     .filter(F.col('category') == v  )
     .groupby(F.col('brand').alias('klarna'),'product.name' ,'ranking_country')
     .agg(F.min('rank').alias('rank'),ranks )
     .orderBy(F.asc('rank'))
     .limit(10)
    ).show(truncate=False)

    all_brands_str = (my_products_us
     .filter(F.col('category') == v  )
     .groupby(F.col('brand').alias('all'),'product.name', 'ranking_country')
     .agg(F.min('rank').alias('rank'),ranks )
     .orderBy(F.asc('rank'))
     .limit(10)
    ).show(truncate=False)

    rising_brands_str = (my_products_us
#     .filter( (F.col('rank') <  0.9 * F.col('rank_1w')) 
#             &    (F.col('rank_1w') <  0.8 * F.col('rank_2w')) 
#             &    (F.col('rank_2w') < 0.7 * F.col('rank_3w')) 
#               &  (F.col('rank') > 10 ) )
    .filter ( (F.col('rank') <    0.5 * F.col('rank_3w')) 
            &    (F.col('rank_1w') <  F.col('rank_2w')) 
            &    (F.col('rank_2w') <  F.col('rank_3w')) 
              &  (F.col('rank') > 10 ) 
              &  (F.col('rank') < 1000 ) )
                        
     .filter(F.col('category') == v  )
     .groupby(F.col('brand').alias('rising'),'product.name', 'ranking_country')
     .agg(F.min('rank').alias('rank'),ranks )
     .orderBy(F.asc('rank'))
     .limit(5)
    ).show(truncate=False)
#     for a,b,c in zip_longest(my_brands_str.split('\n'),all_brands_str.split('\n'),rising_brands_str.split('\n')):
#         print(b,'' if not a else a,'' if not c else c)
# Out:
# Health & Beauty > Personal Care
# +-------------+---------------------------------------------+---------------+----+-----------------+
# |klarna       |name                                         |ranking_country|rank|ranks            |
# +-------------+---------------------------------------------+---------------+----+-----------------+
# |Bose         |Bose Sleepbuds II                            |US             |250 |319              |
# |Calvin Klein |Calvin Klein Euphoria                        |US             |253 |295 ◄ 555 ◄ 571  |
# |Mario Badescu|Mario Badescu Drying Lotion                  |US             |268 |291 ◄ 306 ◄ 201  |
# |Hot Topic    |Arctic Fox Semi-Permanent Hair Dye           |US             |345 |531 ◄ 1058 ◄ 475 |
# |Love Wellness|Love Wellness pH Balancing Cleanser          |US             |416 |337 ◄ 265 ◄ 269  |
# |Calvin Klein |Calvin Klein Eternity Men                    |US             |549 |371              |
# |Calvin Klein |Calvin Klein Euphoria for Women Eau de Parfum|US             |854 |869 ◄ 628 ◄ 609  |
# |Brookstone   |Brookstone Foot & Calf Massager              |US             |942 |1071 ◄ 1028 ◄ 921|
# |Bio Ionic    |Bio Ionic Long Barrel Styler Pro Curling Iron|US             |986 |1013 ◄ 950 ◄ 819 |
# |Timberland   |Timberland PRO Anti-Fatigue Technology Insole|US             |1230|                 |
# +-------------+---------------------------------------------+---------------+----+-----------------+
#
# +--------------+-------------------------------------------------------------+---------------+----+--------------+
# |all           |name                                                         |ranking_country|rank|ranks         |
# +--------------+-------------------------------------------------------------+---------------+----+--------------+
# |Revlon        |Revlon Pro Collection Salon One-Step Hair Dryer and Volumizer|US             |1   |1 ◄ 3 ◄ 3     |
# |The Ordinary  |The Ordinary AHA 30% + BHA 2% Peeling Solution               |US             |2   |2 ◄ 1         |
# |The Ordinary  |The Ordinary. Niacinamide 10% + Zinc 1%                      |US             |3   |3 ◄ 2 ◄ 2     |
# |Paula's Choice|Paula's Choice Skin Perfecting 2% BHA Liquid Exfoliant       |US             |4   |4 ◄ 4 ◄ 4     |
# |Olaplex       |Olaplex Hair Kit                                             |US             |5   |7             |
# |Olaplex       |Olaplex No.3 Hair Perfector                                  |US             |6   |9 ◄ 6 ◄ 6     |
# |OPI           |OPI Nail Lacquer                                             |US             |7   |5 ◄ 243 ◄ 2278|
# |Dr. Bronner’s |Dr. Bronner's Pure-Castile Liquid Soap                       |US             |8   |16 ◄ 16 ◄ 16  |
# |Manscaped     |Manscaped The Lawn Mower 3.0                                 |US             |9   |8 ◄ 9 ◄ 8     |
# |CeraVe        |CeraVe Renewing SA Cleanser                                  |US             |10  |10 ◄ 15 ◄ 23  |
# +--------------+-------------------------------------------------------------+---------------+----+--------------+
#
# +------------+---------------------------------------------------------+---------------+----+-----------------+
# |rising      |name                                                     |ranking_country|rank|ranks            |
# +------------+---------------------------------------------------------+---------------+----+-----------------+
# |Eyefusion   |Eyefusion Halloween Coloured Contact Lenses              |US             |13  |34 ◄ 97 ◄ 307    |
# |Eyefusion   |Eyefusion 90 Day Colored Contact Lenses                  |US             |14  |26 ◄ 36 ◄ 76     |
# |Dr. Jart+   |Dr. Jart+ Cicapair Tiger Grass Color Correcting Treatment|US             |24  |648 ◄ 1442 ◄ 1476|
# |The Ordinary|The Ordinary. Retinol 0.5% in Squalane                   |US             |54  |51 ◄ 74 ◄ 161    |
# |Eyefusion   |Eyefusion Mystic Colored Contact Lenses                  |US             |83  |152 ◄ 415 ◄ 1490 |
# +------------+---------------------------------------------------------+---------------+----+-----------------+
#
# Home & Garden > Decor
# +------------------+-----------------------------------------------------------------------------------------------------------------------+---------------+----+------------------+
# |klarna            |name                                                                                                                   |ranking_country|rank|ranks             |
# +------------------+-----------------------------------------------------------------------------------------------------------------------+---------------+----+------------------+
# |Lenovo            |Lenovo Smart Clock                                                                                                     |US             |72  |                  |
# |H&M               |H&M Home - Wooden Frame - Brown                                                                                        |US             |349 |218               |
# |Swarovski         |Swarovski Ornament                                                                                                     |US             |596 |710 ◄ 1625        |
# |Inked and Screened|Inked and Screened Poster Sneaker Michael Jordan Shoes Fashion AJ History Poster Air Max Poster Wall Art Painting Print|US             |673 |648 ◄ 523         |
# |Fanatics          |Fanatics Authentic LeBron James Los Angeles Lakers Unsigned Dunk Against Houston Rockets Photograph                    |US             |1298|1418 ◄ 4954 ◄ 4614|
# |iCanvas           |iCanvas Framed Canvas Art Water's Edge I by Carol Robinson                                                             |US             |1546|1751 ◄ 2545 ◄ 2366|
# |Yamazaki          |Yamazaki Plain Coat Hanger                                                                                             |US             |1921|2984 ◄ 2749 ◄ 1888|
# |Swarovski         |Swarovski Annual Edition 2020 Christmas Ornament 5511041                                                               |US             |2784|3948              |
# |Brookstone        |Brookstone 95" Zoey Blackout Embroidered Window Curtain Panel                                                          |US             |3177|4354 ◄ 3600       |
# |Brookstone        |Brookstone Troy Window Curtain Panel                                                                                   |US             |3480|7621              |
# +------------------+-----------------------------------------------------------------------------------------------------------------------+---------------+----+------------------+
#
# +---------------+------------------------------------------------------------------+---------------+----+----------------+
# |all            |name                                                              |ranking_country|rank|ranks           |
# +---------------+------------------------------------------------------------------+---------------+----+----------------+
# |Ashland        |Craft Pumpkin By Ashland                                          |US             |1   |                |
# |Room Essentials|Room Essentials Wedge Poster Frame Black                          |US             |2   |3 ◄ 3 ◄ 13      |
# |Mercury Row    |Martinsen Full Length Mirror Mercury Row Finish                   |US             |3   |6 ◄ 5 ◄ 2       |
# |null           |SEPHORA COLLECTION Wild Wishes Advent Calendar                    |US             |4   |17 ◄ 27 ◄ 74    |
# |Unique Loom    |Unique Loom Solid Shag Area Rug                                   |US             |5   |117 ◄ 794 ◄ 1581|
# |Room Essentials|Room Essentials Tube Profile Poster Frame                         |US             |6   |10 ◄ 8 ◄ 15     |
# |Unique Loom    |Unique Loom Casino Sofia Area Rug                                 |US             |7   |1030 ◄ 14 ◄ 357 |
# |null           |Donald Trump for President 2020 Keep America Great Flag 3x5 Feet w|US             |8   |12 ◄ 4 ◄ 6      |
# |Hallmark       |2020 Hallmark Ornament                                            |US             |9   |8696 ◄ 23 ◄ 64  |
# |null           |Infinity Shag Area Rug                                            |US             |10  |16 ◄ 11 ◄ 14    |
# +---------------+------------------------------------------------------------------+---------------+----+----------------+
#
# +--------------------+-------------------------------------------------------------------------+---------------+----+----------------+
# |rising              |name                                                                     |ranking_country|rank|ranks           |
# +--------------------+-------------------------------------------------------------------------+---------------+----+----------------+
# |Hyde & EEK! Boutique|Hyde & EEK! Boutique Halloween Lifesize Poseable Skeleton Halloween Decor|US             |15  |11 ◄ 12 ◄ 107   |
# |null                |Homesick Candle                                                          |US             |20  |31 ◄ 7521 ◄ 7874|
# |null                |Hearth & Hand with Magnolia Large Round Wall Mirror                      |US             |37  |42 ◄ 90 ◄ 623   |
# |null                |Winter Wonderland Personalized Christmas Stocking D2477995               |US             |38  |72 ◄ 122 ◄ 264  |
# |Hyde & EEK! Boutique|Hyde & EEK! Boutique Halloween Carvable Plastic Halloween Pumpkin        |US             |39  |26 ◄ 37 ◄ 222   |
# +--------------------+-------------------------------------------------------------------------+---------------+----+----------------+
#
# Health & Beauty > Health Care
# +-------------+------------------------------------------------------------------------------------------+---------------+----+------------------+
# |klarna       |name                                                                                      |ranking_country|rank|ranks             |
# +-------------+------------------------------------------------------------------------------------------+---------------+----+------------------+
# |Love Wellness|Love Wellness The Killer                                                                  |US             |10  |10 ◄ 9 ◄ 10       |
# |Love Wellness|Love Wellness Good                                                                        |US             |62  |80 ◄ 85 ◄ 85      |
# |Love Wellness|Love Wellness Metabolove                                                                  |US             |86  |73 ◄ 54 ◄ 42      |
# |Love Wellness|Love Wellness Bye Bye                                                                     |US             |171 |127 ◄ 106 ◄ 92    |
# |Love Wellness|Love Wellness #Mood Pills                                                                 |US             |308 |393 ◄ 357 ◄ 342   |
# |Love Wellness|Love Wellness UTI don't think so Urinary Tract Health Supplement                          |US             |1373|                  |
# |Love Wellness|Love Wellness Other Love Wellness Lights Out                                              |US             |2509|                  |
# |Love Wellness|Love Wellness New You Kit                                                                 |US             |2777|2898 ◄ 2878 ◄ 2078|
# |Burton       |Burton Impact Wrist Guard                                                                 |US             |4139|4528 ◄ 5375       |
# |Love Wellness|Love Wellness Balanced Body Kit Women Dietary Supplements Inside And Out Health And Beauty|US             |5428|                  |
# +-------------+------------------------------------------------------------------------------------------+---------------+----+------------------+
#
# +----------------+---------------------------------------------------------+---------------+----+------------+
# |all             |name                                                     |ranking_country|rank|ranks       |
# +----------------+---------------------------------------------------------+---------------+----+------------+
# |Hum Nutrition   |HUM NUTRITION Supplement                                 |US             |1   |1 ◄ 1 ◄ 1   |
# |Fitbit          |Fitbit Versa 2                                           |US             |2   |2 ◄ 8 ◄ 11  |
# |Vital Proteins  |Collagen Peptides Vital Proteins                         |US             |3   |3 ◄ 3 ◄ 5   |
# |Live Well       |Collagen Peptides Hair, Skin, Nail, and Joint Support    |US             |4   |            |
# |Forces of Nature|Forces of Nature Acne/Pimple Control                     |US             |5   |5 ◄ 7 ◄ 13  |
# |Baby Doppler    |Sonoline B Fetal Doppler 3MHz Probe                      |US             |6   |            |
# |Sanitec         |Berrcom Infrared Non-Contact Thermometer                 |US             |7   |16 ◄ 32 ◄ 30|
# |goli            |Apple Cider Vinegar Gummies Goli Nutrition               |US             |8   |12 ◄ 14 ◄ 21|
# |Love Wellness   |Love Wellness The Killer                                 |US             |10  |10 ◄ 9 ◄ 10 |
# |Sharper Image   |Sharper Image Calming Heat Massaging Weighted Heating Pad|US             |12  |            |
# +----------------+---------------------------------------------------------+---------------+----+------------+
#
# +-------------+-----------------------------------------------+---------------+----+-------------+
# |rising       |name                                           |ranking_country|rank|ranks        |
# +-------------+-----------------------------------------------+---------------+----+-------------+
# |Swan         |Swan 70% Isopropyl Alcohol                     |US             |16  |25 ◄ 35 ◄ 47 |
# |null         |Pure Enrichment PureRelief Deluxe Heating Pad  |US             |17  |28 ◄ 39 ◄ 44 |
# |Plan B       |Plan B One Step Emergency Contraceptive        |US             |24  |27 ◄ 38 ◄ 61 |
# |Mommy's Bliss|Mommy's Bliss Baby Constipation Ease           |US             |33  |38 ◄ 59 ◄ 217|
# |iProven      |iProven OXI-27 Fingertip Oximeter monitor Pulse|US             |44  |34 ◄ 40 ◄ 162|
# +-------------+-----------------------------------------------+---------------+----+-------------+
#
# Furniture
# +-------------+-------------------------------------------------------------------+---------------+----+------------------+
# |klarna       |name                                                               |ranking_country|rank|ranks             |
# +-------------+-------------------------------------------------------------------+---------------+----+------------------+
# |PlushBeds    |PlushBeds Natural Latex Sofa Bed Mattress                          |US             |515 |521 ◄ 776 ◄ 904   |
# |Saatva       |Saatva. Ultra-Premium And Eco-Friendly                             |US             |536 |707 ◄ 713 ◄ 869   |
# |Macy's       |Sobro Smart Coffee Table with Refrigerator                         |US             |1278|620 ◄ 674         |
# |Rove Concepts|Noah Sectional Left-hand-facing                                    |US             |1340|2099 ◄ 1852 ◄ 1812|
# |Saatva       |Saatva Our Best Bed For Back Pain                                  |US             |1359|1152 ◄ 1348 ◄ 1489|
# |Macy's       |Radley 86" Fabric Sofa Created for Macy's                          |US             |1427|1634 ◄ 1489 ◄ 1509|
# |Yamazaki     |Yamazaki Tower Rolling Slim Bathroom Cart With Handle              |US             |1603|2021              |
# |Rove Concepts|Nico Sofa - Fin                                                    |US             |1718|1966 ◄ 2310 ◄ 2492|
# |Yamazaki     |Yamazaki Tower Rolling Slim Storage Cart With Handle               |US             |1825|6513              |
# |Saatva       |Hotel Collection Mattress By Saatva. Ultra-Premium And Eco-Friendly|US             |2044|2538 ◄ 3118 ◄ 2866|
# +-------------+-------------------------------------------------------------------+---------------+----+------------------+
#
# +--------------------+------------------------------------------------------------+---------------+----+---------------+
# |all                 |name                                                        |ranking_country|rank|ranks          |
# +--------------------+------------------------------------------------------------+---------------+----+---------------+
# |null                |Aadvik Tufted Upholstered Low Profile Standard Bed Greyleigh|US             |1   |1 ◄ 1          |
# |Andover Mills       |Seraphine Twin Daybed with Trundle Andover Mills            |US             |2   |15 ◄ 18 ◄ 10   |
# |Room Essentials     |Room Essentials 6-Cube Organizer Shelf 11" Mint             |US             |3   |               |
# |Sealy               |Sealy Conform 5" Low Profile Foundation                     |US             |4   |3 ◄ 10         |
# |Room Essentials     |Room Essentials 5 Shelf Bookcase White                      |US             |5   |4 ◄ 5 ◄ 23     |
# |Sealy               |Sealy - StableSupport Full Box Spring                       |US             |6   |11             |
# |Grain Wood Furniture|Grain Wood Furniture Montauk Solid Wood Bed                 |US             |7   |6 ◄ 2957 ◄ 6488|
# |Three Posts         |Lorraine TV Stand for TVs up to 60" Three Posts             |US             |9   |17 ◄ 51 ◄ 76   |
# |Lexington           |Lexington 3-Tier Rolling Cart by Recollections              |US             |10  |               |
# |Adams               |Adams RealComfort Adirondack Chair                          |US             |11  |81 ◄ 34 ◄ 55   |
# +--------------------+------------------------------------------------------------+---------------+----+---------------+
#
# +-------------------------------+------------------------------------------------------------------------------------------------------------+---------------+----+------------+
# |rising                         |name                                                                                                        |ranking_country|rank|ranks       |
# +-------------------------------+------------------------------------------------------------------------------------------------------------+---------------+----+------------+
# |Andover Mills                  |Matheney Platform Bed Andover Mills                                                                         |US             |15  |19 ◄ 27 ◄ 83|
# |null                           |KaiMeng Mid Back Office Chair Ergonomic Computer Chair Desk Chair with Lumbar Support                       |US             |18  |7 ◄ 17 ◄ 69 |
# |Corrigan Studio                |Blomquist Side Chair Corrigan Studio                                                                        |US             |24  |36 ◄ 71 ◄ 79|
# |null                           |Blade 55" Wide Sideboard Longshore Tides Base                                                               |US             |27  |25 ◄ 37 ◄ 67|
# |Laurel Foundry Modern Farmhouse|Laurel Foundry Modern Farmhouse Leisa TV Stand Fireplace for TVs up to 55 " with Electric Fireplace Included|US             |30  |29 ◄ 56 ◄ 88|
# +-------------------------------+------------------------------------------------------------------------------------------------------------+---------------+----+------------+
#
# Apparel & Accessories > Jewelry
# +---------+------------------------------------+---------------+----+-----------------+
# |klarna   |name                                |ranking_country|rank|ranks            |
# +---------+------------------------------------+---------------+----+-----------------+
# |Rastaclat|Rastaclat Men's Bracelet            |US             |83  |94 ◄ 78          |
# |SHEIN    |14pcs Skinny Ring Pack              |US             |96  |90 ◄ 140 ◄ 355   |
# |Swarovski|Swarovski Women's Angelic           |US             |115 |                 |
# |SHEIN    |Rhinestone Butterfly Anklet         |US             |119 |82 ◄ 92 ◄ 88     |
# |Hot Topic|Skeleton Hand Ring Bracelet         |US             |120 |220 ◄ 1803 ◄ 2172|
# |Swarovski|Swarovski Birthstone Pendant        |US             |129 |96 ◄ 127 ◄ 718   |
# |Mejuri   |Mejuri Single Mini Hoop             |US             |142 |203 ◄ 202 ◄ 190  |
# |SHEIN    |3pcs Lock & Key Charm Chain Necklace|US             |212 |309 ◄ 556 ◄ 1003 |
# |Diesel   |Diesel Mr. Daddy 2.0                |US             |230 |161 ◄ 248 ◄ 220  |
# |SHEIN    |1pc Serpentine Shaped Ring          |US             |241 |187 ◄ 171 ◄ 247  |
# +---------+------------------------------------+---------------+----+-----------------+
#
# +-------+------------------------------------------------------------------------+---------------+----+------------+
# |all    |name                                                                    |ranking_country|rank|ranks       |
# +-------+------------------------------------------------------------------------+---------------+----+------------+
# |Apple  |Apple Watch Series 3                                                    |US             |1   |1 ◄ 1 ◄ 1   |
# |Apple  |Apple Watch Series 6                                                    |US             |2   |2 ◄ 3 ◄ 2   |
# |Apple  |Apple Watch SE                                                          |US             |3   |3 ◄ 2 ◄ 3   |
# |null   |Rings Size Guide Find Your Ring                                         |US             |4   |5 ◄ 4 ◄ 4   |
# |null   |Figure out ring size International ring size Chart How to determine ring|US             |5   |4 ◄ 5 ◄ 5   |
# |null   |Bond Touch Bracelets                                                    |US             |6   |6 ◄ 9       |
# |Samsung|Samsung Galaxy Watch Active                                             |US             |7   |10 ◄ 16 ◄ 15|
# |Samsung|Samsung Galaxy Watch                                                    |US             |8   |9 ◄ 18 ◄ 21 |
# |null   |Add a Birthstone or Pearl Charm 5mm Large                               |US             |9   |8 ◄ 7 ◄ 9   |
# |VTech  |VTech DX2                                                               |US             |10  |11 ◄ 21 ◄ 33|
# +-------+------------------------------------------------------------------------+---------------+----+------------+
#
# +------+--------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+---------------+
# |rising|name                                                                                                                                        |ranking_country|rank|ranks          |
# +------+--------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+---------------+
# |null  |Ring size chart                                                                                                                             |US             |11  |16 ◄ 24 ◄ 44   |
# |null  |LIMITED TIME SPECIAL! 2.5 CT.T.W. Lab-Created White Sapphire Stud Earrings in Sterling Silver                                               |US             |14  |12 ◄ 15 ◄ 34   |
# |null  |Sterling Silver Chain Necklace Rhodium Finished Layering Layered Cable-Wheat-Franco 16 18 20 22 24 30 36 inch Sterling Silver Rhodium Plated|US             |22  |107 ◄ 350 ◄ 664|
# |null  |Stainless Steel Apple Watch Milanese Loop                                                                                                   |US             |29  |29 ◄ 47 ◄ 61   |
# |null  |14K Gold Stud Screw Back Birthstone Earrings for all ages ON SALE THIS WEEK                                                                 |US             |52  |80 ◄ 264 ◄ 500 |
# +------+--------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+---------------+
#
# Sporting Goods
# +----------+--------------------------------------------------------------------+---------------+----+------------------+
# |klarna    |name                                                                |ranking_country|rank|ranks             |
# +----------+--------------------------------------------------------------------+---------------+----+------------------+
# |Jetson    |Jetson Sphere Hoverboard                                            |US             |68  |134 ◄ 217 ◄ 269   |
# |Jetson    |Jetson Jupiter Kick Scooter with LED Lights                         |US             |93  |107 ◄ 123 ◄ 113   |
# |Jetson    |Jetson Bolt                                                         |US             |207 |98 ◄ 130 ◄ 204    |
# |TaylorMade|TaylorMade M2 Driver                                                |US             |582 |582 ◄ 8674 ◄ 552  |
# |TaylorMade|TaylorMade 2019 Select Stand Bag                                    |US             |624 |599 ◄ 878 ◄ 1187  |
# |Jetson    |Jetson Force Light-Up Extreme Terrain Hoverboard and Go Kart Combo  |US             |649 |542 ◄ 725 ◄ 4712  |
# |Burton    |Burton Freestyle Snowboard Bindings                                 |US             |789 |1893 ◄ 2705 ◄ 4009|
# |Jetson    |Jetson Saturn Folding 3-Wheel Kick Scooter with Light-Up Stem & Deck|US             |985 |1051 ◄ 1268       |
# |Burton    |Burton Women's Mint Boa Snowboard Boot                              |US             |1005|2291              |
# |adidas    |adidas Eco Friendly 8mm Yoga Mat                                    |US             |1054|1850 ◄ 3928 ◄ 2316|
# +----------+--------------------------------------------------------------------+---------------+----+------------------+
#
# +---------------+----------------------------------------------------------------+---------------+----+---------------+
# |all            |name                                                            |ranking_country|rank|ranks          |
# +---------------+----------------------------------------------------------------+---------------+----+---------------+
# |Bowflex        |Bowflex SelectTech Adjustable                                   |US             |1   |12 ◄ 13        |
# |Schwinn        |Schwinn Indoor Cycling Bike                                     |US             |2   |5 ◄ 7 ◄ 6      |
# |CAP Barbell    |Dumbbell All in Motion                                          |US             |5   |2 ◄ 1          |
# |null           |METIS Neoprene Hex Dumbbells Choose from 1lb -22lbs Free Weights|US             |6   |3 ◄ 5          |
# |Rogue Fitness  |Rogue Kettlebell - 9lb                                          |US             |7   |6 ◄ 3 ◄ 2      |
# |Killer Instinct|Killer Instinct Lethal 405 Crossbow Package                     |US             |8   |9 ◄ 20         |
# |Penn           |Penn Championship Duty Tennis Balls                             |US             |9   |10             |
# |null           |Echelon Smart Connect Bike EX1                                  |US             |10  |15 ◄ 23        |
# |CAP Barbell    |Cap Barbell Coated Hex Dumbbell                                 |US             |11  |468 ◄ 8 ◄ 7733 |
# |null           |Fitness Gear 100 Pound Standard Weight Set, Size: Small         |US             |12  |38 ◄ 198 ◄ 5226|
# +---------------+----------------------------------------------------------------+---------------+----+---------------+
#
# +------------+---------------------------------------------------------------------+---------------+----+---------------+
# |rising      |name                                                                 |ranking_country|rank|ranks          |
# +------------+---------------------------------------------------------------------+---------------+----+---------------+
# |null        |Fitness Gear 100 Pound Standard Weight Set, Size: Small              |US             |12  |38 ◄ 198 ◄ 5226|
# |SOLE Fitness|SOLE F63                                                             |US             |14  |18 ◄ 25 ◄ 40   |
# |Mongoose    |Mongoose Scepter 24" Kids' Mountain Bike                             |US             |32  |31 ◄ 159 ◄ 2830|
# |SPRI        |Spri Deluxe Rubber Dumbbells                                         |US             |33  |34 ◄ 55 ◄ 157  |
# |null        |Hyde & EEK! Boutique Halloween Bean Bag Toss Game Halloween Party Kit|US             |35  |16 ◄ 27 ◄ 321  |
# +------------+---------------------------------------------------------------------+---------------+----+---------------+
#
# Home & Garden > Linens & Bedding
# +-----------+---------------------------------------------------------------------+---------------+----+---------------+
# |klarna     |name                                                                 |ranking_country|rank|ranks          |
# +-----------+---------------------------------------------------------------------+---------------+----+---------------+
# |Fanatics   |Northwest Fleece Throw                                               |US             |20  |16             |
# |Fanatics   |Northwest Company Restructure Raschel Blanket                        |US             |308 |               |
# |IZOD       |IZOD Riley Comforter Set                                             |US             |312 |226 ◄ 467 ◄ 638|
# |Brookstone |Brookstone Bedding Heated Micro-Fleece Blanket                       |US             |349 |462 ◄ 310      |
# |Brookstone |Brookstone Calming Weighted Throw Blanket                            |US             |354 |515 ◄ 655      |
# |Brookstone |Brookstone 4-in-1 Bed Wedge Pillow in Grey                           |US             |389 |443 ◄ 527      |
# |Fanatics   |The Northwest Company 50" x 60" Stabilize Raschel Plush Throw Blanket|US             |444 |1082 ◄ 3924    |
# |Nautica    |Nautica Vessey Quilt                                                 |US             |469 |551 ◄ 721 ◄ 746|
# |Fanatics   |Slant Raschel Blanket                                                |US             |587 |               |
# |Perry Ellis|Perry Ellis Asian Lily Duvet Set                                     |US             |638 |1937 ◄ 1999    |
# +-----------+---------------------------------------------------------------------+---------------+----+---------------+
#
# +------------------------+---------------------------------------------------------------------+---------------+----+------------+
# |all                     |name                                                                 |ranking_country|rank|ranks       |
# +------------------------+---------------------------------------------------------------------+---------------+----+------------+
# |the Comfy               |The Comfy Original Oversized Microfiber & Sherpa Wearable Blanket    |US             |1   |1           |
# |Happy Nappers           |Happy Nappers Pillow                                                 |US             |2   |2           |
# |Purple                  |Purple Pillow                                                        |US             |3   |3 ◄ 3 ◄ 6   |
# |The Big One             |The Big One Supersoft Plush Throw                                    |US             |4   |4 ◄ 105 ◄ 2 |
# |null                    |UGG 2-Piece Reversible Comforter Set                                 |US             |5   |            |
# |Lucid                   |LUCID Memory Foam Mattress Topper                                    |US             |7   |8 ◄ 12 ◄ 4  |
# |the Comfy               |The Comfy Dream Oversized Light Microfiber Wearable Blanket          |US             |8   |16 ◄ 34     |
# |null                    |Snuggle 360 Degree Zippered Mattress Protector                       |US             |9   |9 ◄ 18 ◄ 41 |
# |Lucid                   |Lucid 3-inch Ventilated Gel Memory Foam Mattress Topper              |US             |11  |18 ◄ 53 ◄ 65|
# |Blue Ridge Home Fashions|Kathy Ireland 240 Thread Count White Goose Feather and Down Comforter|US             |12  |19 ◄ 15 ◄ 8 |
# +------------------------+---------------------------------------------------------------------+---------------+----+------------+
#
# +----------------+-----------------------------------------------------------------------+---------------+----+-----------------+
# |rising          |name                                                                   |ranking_country|rank|ranks            |
# +----------------+-----------------------------------------------------------------------+---------------+----+-----------------+
# |Lucid           |Lucid 3-inch Ventilated Gel Memory Foam Mattress Topper                |US             |11  |18 ◄ 53 ◄ 65     |
# |Tempur          |Tempur Pedic Tempur-Adapt Cloud + Cooling Pillow                       |US             |15  |17 ◄ 23 ◄ 34     |
# |Rumpl           |Rumpl Original Puffy Blanket                                           |US             |17  |36 ◄ 431 ◄ 882   |
# |The Sheet People|Queen Sheets Queen Size Bed Sheet Set 1800 Thread Count Egyptian Sheets|US             |19  |215 ◄ 4825 ◄ 7846|
# |House of Hampton|Lafond Teddy Bear Single Duvet Cover House of Hampton                  |US             |36  |67 ◄ 561 ◄ 6333  |
# +----------------+-----------------------------------------------------------------------+---------------+----+-----------------+
#
# Electronics > Audio
# +------+-------------------------+---------------+----+--------------+
# |klarna|name                     |ranking_country|rank|ranks         |
# +------+-------------------------+---------------+----+--------------+
# |Bose  |Bose QuietComfort 35 II  |US             |4   |4 ◄ 61 ◄ 77   |
# |JBL   |JBL Flip 5               |US             |9   |7 ◄ 11 ◄ 17   |
# |Bose  |Bose Sport Earbuds       |US             |21  |              |
# |JBL   |JBL Charge 4             |US             |23  |19 ◄ 20 ◄ 49  |
# |Bose  |Bose QuietComfort Earbuds|US             |24  |18 ◄ 17       |
# |Bose  |Bose SoundLink Revolve   |US             |28  |30 ◄ 202 ◄ 189|
# |JBL   |JBL Clip 3               |US             |33  |34 ◄ 29 ◄ 72  |
# |Bose  |Bose SoundLink Color II  |US             |41  |41 ◄ 62 ◄ 60  |
# |Bose  |Bose Solo 5              |US             |50  |64 ◄ 84 ◄ 85  |
# |Bose  |Bose SoundSport Wireless |US             |62  |69 ◄ 66 ◄ 98  |
# +------+-------------------------+---------------+----+--------------+
#
# +-------+----------------------------------------+---------------+----+------------+
# |all    |name                                    |ranking_country|rank|ranks       |
# +-------+----------------------------------------+---------------+----+------------+
# |Apple  |Apple AirPods 2                         |US             |1   |1 ◄ 2 ◄ 3   |
# |Apple  |Apple AirPods Pro                       |US             |2   |2 ◄ 1 ◄ 1   |
# |Apple  |Apple EarPods                           |US             |3   |3 ◄ 4 ◄ 4   |
# |Bose   |Bose QuietComfort 35 II                 |US             |4   |4 ◄ 61 ◄ 77 |
# |Amazon |Amazon Echo Dot (3 Gen.)                |US             |5   |5 ◄ 10 ◄ 7  |
# |Beats  |Apple Beats Solo3                       |US             |6   |6 ◄ 7 ◄ 8   |
# |Samsung|Samsung Galaxy Buds+                    |US             |7   |10 ◄ 12 ◄ 14|
# |null   |Apple Wireless Charging Case for AirPods|US             |8   |8 ◄ 26 ◄ 359|
# |JBL    |JBL Flip 5                              |US             |9   |7 ◄ 11 ◄ 17 |
# |Beats  |Apple Beats Studio3                     |US             |10  |14 ◄ 22 ◄ 11|
# +-------+----------------------------------------+---------------+----+------------+
#
# +------+------------------+---------------+----+-------------+
# |rising|name              |ranking_country|rank|ranks        |
# +------+------------------+---------------+----+-------------+
# |Google|Google Nest Mini  |US             |13  |22 ◄ 31 ◄ 37 |
# |JBL   |JBL Charge 4      |US             |23  |19 ◄ 20 ◄ 49 |
# |Apple |Apple AirPods     |US             |29  |67 ◄ 92 ◄ 113|
# |Apple |Apple HomePod     |US             |34  |35 ◄ 69 ◄ 93 |
# |Amazon|Amazon Echo Show 8|US             |35  |37 ◄ 81 ◄ 90 |
# +------+------------------+---------------+----+-------------+
#
# Toys & Games
# +------+----+---------------+----+-----+
# |klarna|name|ranking_country|rank|ranks|
# +------+----+---------------+----+-----+
# +------+----+---------------+----+-----+
#
# +----------------+--------------------------------------------------------------------------------------------------------------+---------------+----+--------------+
# |all             |name                                                                                                          |ranking_country|rank|ranks         |
# +----------------+--------------------------------------------------------------------------------------------------------------+---------------+----+--------------+
# |Mattel          |Star Wars Mandalorian The Child Plush                                                                         |US             |1   |              |
# |L.O.L. Surprise!|L.O.L. Surprise! O.M.G. Remix Super Surprise                                                                  |US             |2   |5 ◄ 23 ◄ 33   |
# |Little Live Pets|Little Live Pets Gotta Go Flamingo                                                                            |US             |3   |2 ◄ 7         |
# |null            |Kidzone DIY Race #00-99 6V Kids Toy Electric Ride On Bumper Car Vehicle Remote Control 360 Spin ASTM-certified|US             |4   |9 ◄ 6 ◄ 5     |
# |Baby Alive      |Hasbro Baby Alive Baby Grows Up                                                                               |US             |5   |              |
# |LEGO            |LEGO 71360 Super Mario Adventures with Mario Starter Course                                                   |US             |6   |4 ◄ 5 ◄ 1     |
# |L.O.L. Surprise!|L.O.L. Surprise! O.M.G. Remix Fashion Doll 25 Surprises with Music                                            |US             |7   |              |
# |Hot Wheels      |Hot Wheels City Ultimate Garage                                                                               |US             |8   |12 ◄ 37 ◄ 164 |
# |Little Tikes    |Little Tikes 3' Trampoline                                                                                    |US             |9   |14 ◄ 11 ◄ 11  |
# |ZURU            |Zuru 5 Surprise Mini Brands                                                                                   |US             |10  |48 ◄ 17 ◄ 5507|
# +----------------+--------------------------------------------------------------------------------------------------------------+---------------+----+--------------+
#
# +------+---------------------------------------------------------------------------------+---------------+----+------------------+
# |rising|name                                                                             |ranking_country|rank|ranks             |
# +------+---------------------------------------------------------------------------------+---------------+----+------------------+
# |null  |Hyde & EEK! Boutique Halloween 6ct Toy Filled Mini Pumpkin Halloween Party Favors|US             |15  |8 ◄ 17 ◄ 65       |
# |null  |Pokemon xy12 Elite Trainer Box                                                   |US             |17  |31 ◄ 35 ◄ 46      |
# |Funko |FUNKO POP!                                                                       |US             |26  |6454 ◄ 7870 ◄ 9878|
# |LEGO  |LEGO 75280 Star Wars 501st Legion Clone Troopers                                 |US             |27  |49 ◄ 125 ◄ 349    |
# |LEGO  |LEGO 71369 Super Mario Bowser's Castle Boss Battle                               |US             |28  |30 ◄ 69 ◄ 94      |
# +------+---------------------------------------------------------------------------------+---------------+----+------------------+
#
# Apparel & Accessories > Clothing
# +-----------------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+----------------+
# |klarna           |name                                                                                                                                            |ranking_country|rank|ranks           |
# +-----------------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+----------------+
# |SHEIN            |Solid Waterfall Collar Double Breasted Women Coat Pea Coat Polyester Brown Polyester Plain Button Front Double Breasted Midi Long Sleeve Elegant|US             |3   |210 ◄ 4 ◄ 4     |
# |adidas           |adidas Men's Soccer Tiro 19 Training Pants                                                                                                      |US             |24  |56 ◄ 30 ◄ 36    |
# |The North Face   |The North Face Women's Osito Jacket                                                                                                             |US             |37  |34 ◄ 37 ◄ 2797  |
# |The North Face   |The North Face Women's Gotham II Jacket                                                                                                         |US             |40  |164             |
# |SHEIN            |Notched Collar Plaid Blazer & Skirt Set Yellow Tartan Cotton Cotton Polyester Young Preppy Zipper Blazer                                        |US             |54  |371 ◄ 182 ◄ 739 |
# |SHEIN            |Solid Fold Pleated Skater Skirt Black Plain Flared Polyester Polyester Spandex Mini Zipper Pleated Preppy Young                                 |US             |76  |93 ◄ 115 ◄ 156  |
# |Fanatics         |Men's Fanatics Branded Los Angeles Lakers Black 2020 Western Conference Champions Drive T-Shirt                                                 |US             |81  |65 ◄ 1265 ◄ 5688|
# |Aéropostale      |Aeropostale Guys' Classic Twill Joggers                                                                                                         |US             |96  |137 ◄ 276 ◄ 387 |
# |PrettyLittleThing|Women's PrettyLittleThing Shape PU Split Hem Pants                                                                                              |US             |104 |88 ◄ 107        |
# |Fanatics         |Men's Fanatics Branded LeBron James Purple Los Angeles Lakers 2018/19 Fast Break Replica Jersey                                                 |US             |123 |                |
# +-----------------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+----------------+
#
# +--------------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+---------------+
# |all           |name                                                                                                                                            |ranking_country|rank|ranks          |
# +--------------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+---------------+
# |Nike          |Nike Sportswear Men's Fleece Trousers                                                                                                           |US             |1   |1 ◄ 1 ◄ 2      |
# |Old Navy      |Old Navy Women's High-Waisted Balance Yoga Leggings                                                                                             |US             |2   |8 ◄ 15 ◄ 12    |
# |SHEIN         |Solid Waterfall Collar Double Breasted Women Coat Pea Coat Polyester Brown Polyester Plain Button Front Double Breasted Midi Long Sleeve Elegant|US             |3   |210 ◄ 4 ◄ 4    |
# |Old Navy      |Old Navy Women's Mid-Rise Tapered-Leg Jogger Pants                                                                                              |US             |4   |6 ◄ 14 ◄ 16    |
# |Old Navy      |Old Navy Women's Classic Plaid Flannel Shirt                                                                                                    |US             |5   |4 ◄ 5 ◄ 5      |
# |Nike          |Nike Men's Sportswear Club Fleece Pullover Hoodie                                                                                               |US             |6   |6 ◄ 6695 ◄ 8839|
# |Old Navy      |Old Navy Women's High-Waisted Slim Boot-Cut Yoga Pants                                                                                          |US             |7   |3 ◄ 6 ◄ 21     |
# |American Eagle|AE Fleece Oversized Crew Sweatshirt Women's                                                                                                     |US             |8   |25 ◄ 36 ◄ 8    |
# |SPANX         |Spanx Faux Leather Leggings Women's                                                                                                             |US             |9   |11 ◄ 11 ◄ 10   |
# |Nike          |Nike Men's Everyday Plus Cushion Crew Socks                                                                                                     |US             |10  |7 ◄ 17         |
# +--------------+------------------------------------------------------------------------------------------------------------------------------------------------+---------------+----+---------------+
#
# +---------+---------------------------------------------------------+---------------+----+---------------+
# |rising   |name                                                     |ranking_country|rank|ranks          |
# +---------+---------------------------------------------------------+---------------+----+---------------+
# |Nike     |Nike Men's Sportswear Club Fleece Full-Zip Hoodie        |US             |14  |14 ◄ 17 ◄ 7633 |
# |Gap      |Gap Factory Women's Long Top Coat                        |US             |15  |20 ◄ 267 ◄ 5131|
# |Patagonia|Patagonia Women's Better Sweater 1/4 Zip                 |US             |16  |48 ◄ 184 ◄ 6775|
# |Gap      |Gap Factory Toddler Toddler Coldcontrol Max Puffer Jacket|US             |18  |22 ◄ 35 ◄ 4046 |
# |Old Navy |Old Navy Kids' Solid Leggings                            |US             |23  |36 ◄ 41 ◄ 69   |
# +---------+---------------------------------------------------------+---------------+----+---------------+
#
# Apparel & Accessories > Shoes
# +----------+-------------------------------------------------+---------------+----+---------------+
# |klarna    |name                                             |ranking_country|rank|ranks          |
# +----------+-------------------------------------------------+---------------+----+---------------+
# |adidas    |adidas Women's Cloudfoam Pure                    |US             |21  |13 ◄ 45 ◄ 99   |
# |adidas    |adidas Originals Kids' Swift Run                 |US             |25  |16             |
# |adidas    |Adidas Women's Swift Run Shoes                   |US             |29  |30 ◄ 15 ◄ 11   |
# |adidas    |Womens Adidas NMD_R1 Shoes                       |US             |60  |               |
# |TOMS      |Toms Women's Classic Canvas                      |US             |82  |199 ◄ 224 ◄ 177|
# |adidas    |Adidas Women's Grand Court                       |US             |86  |               |
# |Timberland|Timberland Men's 6 Inch Basic Waterproof Boot    |US             |106 |               |
# |Timberland|Timberland Toddler 6 Premium                     |US             |108 |173            |
# |adidas    |adidas Women's Originals Swift Run X Casual Shoes|US             |125 |202 ◄ 153 ◄ 701|
# |adidas    |adidas Men's Lite Racer Adapt 3.0 Shoes          |US             |150 |               |
# +----------+-------------------------------------------------+---------------+----+---------------+
#
# +---------+---------------------------------------------------------------+---------------+----+-----------------+
# |all      |name                                                           |ranking_country|rank|ranks            |
# +---------+---------------------------------------------------------------+---------------+----+-----------------+
# |Nike     |Nike Air Force 1 '07                                           |US             |1   |1 ◄ 2862 ◄ 298   |
# |Nike     |Nike Air Force 1 Low Youth                                     |US             |2   |2 ◄ 1 ◄ 1        |
# |Nike     |Nike Women's Air Force 1 '07 LV8                               |US             |3   |3 ◄ 3 ◄ 3        |
# |Crocs    |Classic Lined Clog Crocs                                       |US             |4   |6                |
# |Nike     |Air Jordan Mens 1 Mid                                          |US             |5   |204 ◄ 2458 ◄ 2180|
# |A New Day|Women's A New Day Sidney Microsuede Over the Knee Fashion Boots|US             |6   |8 ◄ 22 ◄ 67      |
# |Crocs    |Crocs Adult Classic Clog                                       |US             |7   |157 ◄ 7 ◄ 74     |
# |UGG      |UGG Women's Fluff Yeah Slide                                   |US             |8   |5260 ◄ 8 ◄ 7892  |
# |Brooks   |Brooks Women's Ghost 12                                        |US             |9   |7 ◄ 13 ◄ 17      |
# |Nike     |Nike Blazer Mid 77 Vintage                                     |US             |10  |12 ◄ 10 ◄ 12     |
# +---------+---------------------------------------------------------------+---------------+----+-----------------+
#
# +------+------------------------------+---------------+----+----------------+
# |rising|name                          |ranking_country|rank|ranks           |
# +------+------------------------------+---------------+----+----------------+
# |UGG   |UGG Women's Classic Short II  |US             |16  |24 ◄ 27 ◄ 196   |
# |adidas|adidas Women's Cloudfoam Pure |US             |21  |13 ◄ 45 ◄ 99    |
# |UGG   |Toddler UGG Classic II        |US             |23  |28 ◄ 7111 ◄ 8536|
# |Crocs |Crocs Kids' Classic Lined Clog|US             |40  |50 ◄ 92 ◄ 6460  |
# |Sperry|Sperry Women's Saltwater      |US             |49  |85 ◄ 111 ◄ 123  |
# +------+------------------------------+---------------+----+----------------+
#
# Luggage & Bags
# +--------------+---------------------------------+---------------+----+-----------------+
# |klarna        |name                             |ranking_country|rank|ranks            |
# +--------------+---------------------------------+---------------+----+-----------------+
# |JanSport      |JanSport SuperBreak              |US             |3   |3 ◄ 2 ◄ 2        |
# |The North Face|The North Face Jester            |US             |11  |15 ◄ 5 ◄ 4       |
# |The North Face|The North Face Borealis Backpack |US             |13  |22 ◄ 4788 ◄ 6    |
# |The North Face|The North Face Terra             |US             |19  |134 ◄ 2501 ◄ 2399|
# |The North Face|The North Face Base Camp Duffel  |US             |23  |33 ◄ 33 ◄ 35     |
# |adidas        |adidas Defender III Duffel Bag   |US             |33  |3975 ◄ 27 ◄ 288  |
# |JanSport      |JanSport Right Pack              |US             |42  |35 ◄ 22 ◄ 11     |
# |The North Face|The North Face Lumbar Pack       |US             |43  |136 ◄ 67 ◄ 98    |
# |The North Face|The North Face Top Loader Daypack|US             |49  |42 ◄ 45 ◄ 30     |
# |JanSport      |Cross Town Backpack Jansport     |US             |51  |78 ◄ 70          |
# +--------------+---------------------------------+---------------+----+-----------------+
#
# +--------------+------------------------------------+---------------+----+---------------+
# |all           |name                                |ranking_country|rank|ranks          |
# +--------------+------------------------------------+---------------+----+---------------+
# |COACH         |Coach Charlie Backpack              |US             |1   |2 ◄ 3 ◄ 16     |
# |Fjällräven    |Fjällräven Kånken                   |US             |2   |4 ◄ 15 ◄ 12    |
# |JanSport      |JanSport SuperBreak                 |US             |3   |3 ◄ 2 ◄ 2      |
# |Sprayground   |Sprayground Backpack                |US             |4   |1 ◄ 1 ◄ 1      |
# |Samsonite     |Samsonite Freeform Spinner          |US             |5   |24 ◄ 796 ◄ 1382|
# |Pottery Barn  |Pottery Barn Kids Mackenzie Backpack|US             |6   |68 ◄ 9 ◄ 47    |
# |COACH         |Coach Jordyn Backpack               |US             |7   |10 ◄ 19 ◄ 102  |
# |Patagonia     |Patagonia Women's Tamangito 20L Pack|US             |9   |14 ◄ 696 ◄ 127 |
# |Patagonia     |Patagonia Atom Sling                |US             |10  |11 ◄ 21 ◄ 22   |
# |The North Face|The North Face Jester               |US             |11  |15 ◄ 5 ◄ 4     |
# +--------------+------------------------------------+---------------+----+---------------+
#
# +-----------+----------------------------------------------+---------------+----+---------------+
# |rising     |name                                          |ranking_country|rank|ranks          |
# +-----------+----------------------------------------------+---------------+----+---------------+
# |Disney     |Disney Princess Style Collection Play Suitcase|US             |17  |16 ◄ 25 ◄ 43   |
# |COACH      |Coach Elle Women's Backpack                   |US             |36  |40 ◄ 170 ◄ 3176|
# |TAG Heuer  |Tag Springfield III 5-Piece Set               |US             |41  |79 ◄ 111 ◄ 166 |
# |Osprey     |Osprey Porter                                 |US             |47  |50 ◄ 222 ◄ 302 |
# |Eddie Bauer|Eddie Bauer Cascade Back Pack Diaper Bag      |US             |60  |49 ◄ 74 ◄ 148  |
# +-----------+----------------------------------------------+---------------+----+---------------+
#
# Home & Garden > Kitchen & Dining
# +---------+-------------------------------------------------------------------------+---------------+----+------------------+
# |klarna   |name                                                                     |ranking_country|rank|ranks             |
# +---------+-------------------------------------------------------------------------+---------------+----+------------------+
# |Dalstrong|DALSTRONG Knife Gladiator Series                                         |US             |981 |842 ◄ 829 ◄ 1013  |
# |Fanatics |Corkcicle Stemless                                                       |US             |1488|                  |
# |Dalstrong|Dalstrong Knife Shogun Series                                            |US             |1716|2127 ◄ 4799       |
# |Yamazaki |Yamazaki Tower Dish Drainer Rack                                         |US             |2450|1937              |
# |Dalstrong|Dalstrong Chef Knife 8" Shadow Black Series Black Titanium Nitride Coated|US             |2451|1795 ◄ 812        |
# |Fanatics |20oz. Stealth Water Bottle                                               |US             |3551|4938 ◄ 7322       |
# |Yamazaki |Yamazaki Tosca Wood-Top Stackable Kitchen Rack                           |US             |3590|4647 ◄ 4843 ◄ 3584|
# |Fanatics |6-Piece Can & Bottle Cooler Variety Pack                                 |US             |3667|2746 ◄ 2114 ◄ 1611|
# |Reebok   |Que Expandable Bottle                                                    |US             |3941|                  |
# |Fanatics |2oz. Personalized Full Color Shot Glass                                  |US             |4026|4492 ◄ 9884       |
# +---------+-------------------------------------------------------------------------+---------------+----+------------------+
#
# +----------+--------------------------------------+---------------+----+--------------+
# |all       |name                                  |ranking_country|rank|ranks         |
# +----------+--------------------------------------+---------------+----+--------------+
# |Ball      |Ball Mason Regular Mouth Jars         |US             |1   |1 ◄ 1         |
# |KitchenAid|KitchenAid Artisan KSM150PS           |US             |2   |2 ◄ 2 ◄ 3     |
# |YETI      |YETI Rambler Tumbler                  |US             |3   |3 ◄ 467 ◄ 6346|
# |KitchenAid|KitchenAid Classic Plus KSM75         |US             |4   |5 ◄ 39 ◄ 73   |
# |Ninja     |Ninja Foodi Digital Air Fry Oven SP101|US             |5   |13 ◄ 5 ◄ 8    |
# |Ninja     |Ninja Foodi 5-in-1 Indoor Grill       |US             |6   |36 ◄ 9 ◄ 20   |
# |null      |Galanz Chest Freezer                  |US             |7   |12 ◄ 299      |
# |Ninja     |Ninja Foodi FG551                     |US             |8   |              |
# |YETI      |Yeti Rambler Bottle with Chug Cap     |US             |9   |6 ◄ 6 ◄ 5     |
# |Insignia  |Insignia NS-CZ50WH0                   |US             |10  |8 ◄ 7 ◄ 7     |
# +----------+--------------------------------------+---------------+----+--------------+
#
# +-----------+------------------------------------------------------+---------------+----+--------------+
# |rising     |name                                                  |ranking_country|rank|ranks         |
# +-----------+------------------------------------------------------+---------------+----+--------------+
# |Nespresso  |De'Longhi Nespresso VertuoPlus                        |US             |22  |30 ◄ 106 ◄ 237|
# |Instant Pot|Instant Pot Duo Crisp + Air Fryer                     |US             |40  |35 ◄ 325 ◄ 440|
# |Ninja      |Ninja Foodi 4-in-1 Indoor Grill with 4-Quart Air Fryer|US             |43  |42 ◄ 149 ◄ 292|
# |Corelle    |Corelle Livingware 16-pc Dinnerware Set               |US             |50  |38 ◄ 235 ◄ 326|
# |Kalorik    |Kalorik AFO 46045                                     |US             |56  |65 ◄ 74 ◄ 142 |
# +-----------+------------------------------------------------------+---------------+----+--------------+
